# %% [markdown]
# This add normalization, best result so far

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, matthews_corrcoef, accuracy_score, balanced_accuracy_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
import random

# %%
# Set random seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.keras.utils.set_random_seed(SEED)  # This sets all random seeds in keras
tf.config.experimental.enable_op_determinism()  # For complete reproducibility

# %%
def load_prot_t5_data(pos_file, neg_file):
    """Load ProtT5 embeddings and align with existing data"""
    # Read positive and negative files
    pos_data = []
    with open(pos_file, 'r') as f:
        for line in f:
            parts = line.strip().split(',')
            entry = parts[0]
            pos = int(parts[1])
            embeddings = [float(x) for x in parts[2:]]
            pos_data.append((entry, pos, embeddings))
            
    neg_data = []
    with open(neg_file, 'r') as f:
        for line in f:
            parts = line.strip().split(',')
            entry = parts[0]
            pos = int(parts[1])
            embeddings = [float(x) for x in parts[2:]]
            neg_data.append((entry, pos, embeddings))
    
    # Convert to dictionaries for easy lookup
    pos_dict = {(entry, pos): emb for entry, pos, emb in pos_data}
    neg_dict = {(entry, pos): emb for entry, pos, emb in neg_data}
    
    return pos_dict, neg_dict

# %%
def prepare_aligned_data(seq_struct_df, pos_dict, neg_dict):
    """Align ProtT5 embeddings with sequence+structure data"""
    embeddings = []
    aligned_indices = []
    
    for idx, row in seq_struct_df.iterrows():
        key = (row['entry'], row['pos'])
        emb = pos_dict.get(key) if row['label'] == 1 else neg_dict.get(key)
        
        if emb is not None:
            embeddings.append(emb)
            aligned_indices.append(idx)
    
    # Convert to numpy array
    X_prot_t5 = np.array(embeddings)
    
    # Get aligned sequence+structure data
    aligned_df = seq_struct_df.iloc[aligned_indices]
    
    return X_prot_t5, aligned_df

# %%
def prepare_sequence_data(df):
    """Convert sequences to integer encoding"""
    alphabet = 'ARNDCQEGHILKMFPSTWYV-'
    char_to_int = dict((c, i) for i, c in enumerate(alphabet))
    
    sequences = df['sequence'].values
    encodings = []
    
    for seq in sequences:
        try:
            integer_encoded = [char_to_int[char] for char in seq]
            encodings.append(integer_encoded)
        except Exception as e:
            print(f"Error processing sequence: {e}")
            continue
    
    return np.array(encodings)

# %%
def prepare_structure_data(df):
    """Enhanced feature preparation focusing on important features"""
    features_list = []
    middle_pos = 16  # Center position
    
    # Helper function for normalization
    def normalize_angles(angle_array):
        angle_rad = np.pi * angle_array / 180.0
        return np.stack([np.sin(angle_rad), np.cos(angle_rad)], axis=-1)
    
    # 1. Most important features (importance > 0.04) - using ±0 window
    important_features = [
        'bfactor',
        'distance_to_center',
        'sasa',
        'omega',
        'domain_position'
    ]
    
    for feature in important_features:
        feature_arrays = np.array([np.array(eval(x)) for x in df[feature]])
        # Take only the center position
        center_values = feature_arrays[:, middle_pos]
        scaler = RobustScaler()
        scaled_values = scaler.fit_transform(center_values.reshape(-1, 1))
        features_list.append(scaled_values)
    
    # 2. Secondary important features (0.03 < importance < 0.04)
    secondary_features = [
        'chi1', 'chi2', 'chi3', 'chi4',
        'curvature', 'psi', 'phi', 'tau',
        'packing_density', 'local_hydrophobicity'
    ]
    
    for feature in secondary_features:
        feature_arrays = np.array([np.array(eval(x)) for x in df[feature]])
        center_values = feature_arrays[:, middle_pos]
        if feature in ['phi', 'psi', 'omega', 'tau']:
            # Angle features get sin/cos encoding
            angle_features = normalize_angles(center_values)
            features_list.append(angle_features)
        else:
            scaler = RobustScaler()
            scaled_values = scaler.fit_transform(center_values.reshape(-1, 1))
            features_list.append(scaled_values)
    
    # 3. Special case: hydrophobicity with ±1 window
    hydro_arrays = np.array([np.array(eval(x)) for x in df['hydrophobicity']])
    hydro_window = hydro_arrays[:, middle_pos-1:middle_pos+2]  # ±1 window
    scaler = RobustScaler()
    hydro_scaled = scaler.fit_transform(hydro_window.reshape(-1, 1)).reshape(len(hydro_arrays), 3)
    features_list.append(hydro_scaled)
    
    # Combine all features
    features = np.concatenate(features_list, axis=-1)
    
    # Add a dimension for the "sequence" length (1 for center position)
    features = features.reshape(features.shape[0], 1, -1)
    
    return features

# %%
def create_combined_model_with_prot_t5(seq_length=33, struct_features=None, struct_window=0):
    regularizer = tf.keras.regularizers.l2(0.01)
    
    # Sequence track
    seq_input = tf.keras.layers.Input(shape=(seq_length,), name='sequence_input')
    x_seq = tf.keras.layers.Embedding(21, 21, input_length=seq_length)(seq_input)
    x_seq = tf.keras.layers.Reshape((seq_length, 21, 1))(x_seq)
    x_seq = tf.keras.layers.Conv2D(32, kernel_size=(17, 3), activation='relu', padding='valid')(x_seq)
    x_seq = tf.keras.layers.BatchNormalization()(x_seq)
    x_seq = tf.keras.layers.Dropout(0.4)(x_seq)
    x_seq = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x_seq)
    x_seq = tf.keras.layers.Flatten()(x_seq)
    x_seq = tf.keras.layers.Dense(32, activation='relu', 
                                 kernel_regularizer=regularizer, 
                                 name='seq_features')(x_seq)
    x_seq = tf.keras.layers.BatchNormalization()(x_seq)
    x_seq = tf.keras.layers.Dropout(0.4)(x_seq)

    # Structure track
    struct_input = tf.keras.layers.Input(shape=(1, struct_features), name='structure_input')
    x_struct = struct_input
    struct_dense_size = min(struct_features * 2, 128)
    
    x_struct = tf.keras.layers.Conv1D(32, 3, padding='same', activation='relu')(x_struct)
    x_struct = tf.keras.layers.BatchNormalization()(x_struct)
    x_struct = tf.keras.layers.Dropout(0.4)(x_struct)
    x_struct = tf.keras.layers.Flatten()(x_struct)
    x_struct = tf.keras.layers.Dense(struct_dense_size, activation='relu',
                                   kernel_regularizer=regularizer)(x_struct)
    x_struct = tf.keras.layers.BatchNormalization()(x_struct)
    x_struct = tf.keras.layers.Dropout(0.4)(x_struct)

    # ProtT5 track
    prot_t5_input = tf.keras.layers.Input(shape=(1024,), name='prot_t5_input')
    x_prot_t5 = tf.keras.layers.Dense(256, kernel_regularizer=regularizer)(prot_t5_input)
    x_prot_t5 = tf.keras.layers.BatchNormalization()(x_prot_t5)
    x_prot_t5 = tf.keras.layers.Dropout(0.5)(x_prot_t5)
    x_prot_t5 = tf.keras.layers.Dense(128, activation='relu',
                                     kernel_regularizer=regularizer)(x_prot_t5)
    x_prot_t5 = tf.keras.layers.BatchNormalization()(x_prot_t5)
    x_prot_t5 = tf.keras.layers.Dropout(0.5)(x_prot_t5)

    # Create learnable weights layer
    weight_layer = tf.keras.layers.Dense(3, activation='softmax', name='track_weights')
    track_weights = weight_layer(tf.keras.layers.Concatenate()([x_seq, x_struct, x_prot_t5]))

    # Apply weights
    weighted_seq = tf.keras.layers.Multiply(name='weighted_seq')([
        x_seq,
        tf.keras.layers.Lambda(lambda x: x[:, 0:1])(track_weights)
    ])
    
    weighted_struct = tf.keras.layers.Multiply(name='weighted_struct')([
        x_struct,
        tf.keras.layers.Lambda(lambda x: x[:, 1:2])(track_weights)
    ])
    
    weighted_prot_t5 = tf.keras.layers.Multiply(name='weighted_prot_t5')([
        x_prot_t5,
        tf.keras.layers.Lambda(lambda x: x[:, 2:3])(track_weights)
    ])

    # Combine features
    combined = tf.keras.layers.Concatenate()([weighted_seq, weighted_struct, weighted_prot_t5])

    # Final layers with more regularization
    x = tf.keras.layers.Dense(64, activation='relu', 
                            kernel_regularizer=regularizer)(combined)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(32, activation='relu', 
                            kernel_regularizer=regularizer)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)

    model = tf.keras.Model(inputs=[seq_input, struct_input, prot_t5_input], outputs=outputs)
    
    def get_track_weights():
        w = model.get_layer('track_weights').get_weights()
        if len(w) > 0:
            weights = w[0]
            bias = w[1] if len(w) > 1 else 0
            exp_weights = np.exp(np.mean(weights, axis=0) + bias)
            normalized = exp_weights / np.sum(exp_weights)
            return {
                'sequence': float(normalized[0]),
                'structure': float(normalized[1]),
                'prot_t5': float(normalized[2])
            }
        return {'sequence': 0.33, 'structure': 0.33, 'prot_t5': 0.34}

    model.get_track_weights = get_track_weights
    return model

# %%
def train_and_evaluate():
    """Training function with track weights"""
    # Load data
    print("Loading data...")
    train_df = pd.read_csv("../data/processed_features_train_latest.csv")
    test_df = pd.read_csv("../data/processed_features_test_latest.csv")
    
    # Load ProtT5 embeddings
    print("Loading ProtT5 embeddings...")
    train_pos_dict, train_neg_dict = load_prot_t5_data(
        '/Users/hai/Workspace/UniFreiburg/WS2024/Thesis/LMSuccSite/data/train/features/train_positive_ProtT5-XL-UniRef50.csv',
        '/Users/hai/Workspace/UniFreiburg/WS2024/Thesis/LMSuccSite/data/train/features/train_negative_ProtT5-XL-UniRef50.csv'
    )
    test_pos_dict, test_neg_dict = load_prot_t5_data(
        '/Users/hai/Workspace/UniFreiburg/WS2024/Thesis/LMSuccSite/data/test/features/test_positive_ProtT5-XL-UniRef50.csv',
        '/Users/hai/Workspace/UniFreiburg/WS2024/Thesis/LMSuccSite/data/test/features/test_negative_ProtT5-XL-UniRef50.csv'
    )
    
    # Align data
    print("Aligning data...")
    X_train_prot_t5, train_df_aligned = prepare_aligned_data(train_df, train_pos_dict, train_neg_dict)
    X_test_prot_t5, test_df_aligned = prepare_aligned_data(test_df, test_pos_dict, test_neg_dict)
    
    # Prepare other data
    X_train_seq = prepare_sequence_data(train_df_aligned)
    X_test_seq = prepare_sequence_data(test_df_aligned)
    X_train_struct = prepare_structure_data(train_df_aligned)
    X_test_struct = prepare_structure_data(test_df_aligned)
    
    y_train = train_df_aligned['label'].values
    y_test = test_df_aligned['label'].values
    
    # Print class distribution
    print("\nTraining set distribution:")
    print(train_df_aligned['label'].value_counts())
    print("\nTest set distribution:")
    print(test_df_aligned['label'].value_counts())
    
    # Print data shapes
    print("\nData shapes:")
    print(f"X_train_seq: {X_train_seq.shape}")
    print(f"X_train_struct: {X_train_struct.shape}")
    print(f"X_train_prot_t5: {X_train_prot_t5.shape}")
    print(f"X_test_seq: {X_test_seq.shape}")
    print(f"X_test_struct: {X_test_struct.shape}")
    print(f"X_test_prot_t5: {X_test_prot_t5.shape}")
    print(f"y_train: {y_train.shape}")
    print(f"y_test: {y_test.shape}")
    
    # Calculate class weights
    total_samples = len(y_train)
    pos_samples = np.sum(y_train == 1)
    neg_samples = np.sum(y_train == 0)
    
    class_weights = {
        0: total_samples / (2 * neg_samples),
        1: total_samples / (2 * pos_samples)
    }
    
    # Cross-validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=42)
    metrics = {'acc': [], 'balanced_acc': [], 'mcc': [], 'sn': [], 'sp': []}
    test_predictions = []
    
    track_weights_history = []
    
    for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train_seq), 1):
        print(f"\nFold {fold}/5")
        
        # Callbacks
        callbacks = [
            tf.keras.callbacks.EarlyStopping(
                monitor='val_loss',
                patience=5,
                restore_best_weights=True
            ),
            tf.keras.callbacks.ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=3,
                min_lr=1e-6
            )
        ]
        
        # Create and compile model
        model = create_combined_model_with_prot_t5(
            seq_length=33,
            struct_features=X_train_struct.shape[2],
            struct_window=0
        )
        
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
            loss='binary_crossentropy',
            metrics=['accuracy']
        )
        
        # Train model
        history = model.fit(
            [X_train_seq[train_idx], X_train_struct[train_idx], X_train_prot_t5[train_idx]], 
            y_train[train_idx],
            validation_data=(
                [X_train_seq[val_idx], X_train_struct[val_idx], X_train_prot_t5[val_idx]], 
                y_train[val_idx]
            ),
            batch_size=32,
            epochs=50,
            callbacks=callbacks,
            class_weight=class_weights,
            verbose=1
        )
        
        # Plot training history
        plt.figure(figsize=(10, 6))
        plt.plot(history.history['accuracy'], label='Train Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title(f'Model Accuracy - Fold {fold}')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()
        plt.show()
        
        # Evaluate on validation set
        y_pred = model.predict([X_train_seq[val_idx], X_train_struct[val_idx], X_train_prot_t5[val_idx]])
        y_pred_binary = (y_pred > 0.5).astype(int)
        
        # Calculate metrics
        cm = confusion_matrix(y_train[val_idx], y_pred_binary)
        metrics['acc'].append(accuracy_score(y_train[val_idx], y_pred_binary))
        metrics['balanced_acc'].append(balanced_accuracy_score(y_train[val_idx], y_pred_binary))
        metrics['mcc'].append(matthews_corrcoef(y_train[val_idx], y_pred_binary))
        metrics['sn'].append(cm[1][1]/(cm[1][1]+cm[1][0]))  # Sensitivity
        metrics['sp'].append(cm[0][0]/(cm[0][0]+cm[0][1]))  # Specificity
        
        # Predict on test set
        test_pred = model.predict([X_test_seq, X_test_struct, X_test_prot_t5])
        test_predictions.append(test_pred)
        
        # Print fold results
        print(f"\nFold {fold} Results:")
        print(f"Accuracy: {metrics['acc'][-1]:.4f}")
        print(f"Balanced Accuracy: {metrics['balanced_acc'][-1]:.4f}")
        print(f"MCC: {metrics['mcc'][-1]:.4f}")
        print(f"Sensitivity: {metrics['sn'][-1]:.4f}")
        print(f"Specificity: {metrics['sp'][-1]:.4f}")
        
        # After training, get and store the learned weights
        final_weights = model.get_track_weights()
        track_weights_history.append(final_weights)
        print(f"\nLearned track weights for fold {fold}:")
        print(f"Sequence weight: {final_weights['sequence']:.4f}")
        print(f"Structure weight: {final_weights['structure']:.4f}")
        print(f"ProtT5 weight: {final_weights['prot_t5']:.4f}")
    
    # Calculate average weights
    avg_seq_weight = np.mean([w['sequence'] for w in track_weights_history])
    avg_struct_weight = np.mean([w['structure'] for w in track_weights_history])
    avg_prot_t5_weight = np.mean([w['prot_t5'] for w in track_weights_history])
    std_seq_weight = np.std([w['sequence'] for w in track_weights_history])
    std_struct_weight = np.std([w['structure'] for w in track_weights_history])
    std_prot_t5_weight = np.std([w['prot_t5'] for w in track_weights_history])
    
    print("\nAverage track weights across folds:")
    print(f"Sequence weight: {avg_seq_weight:.4f} ± {std_seq_weight:.4f}")
    print(f"Structure weight: {avg_struct_weight:.4f} ± {std_struct_weight:.4f}")
    print(f"ProtT5 weight: {avg_prot_t5_weight:.4f} ± {std_prot_t5_weight:.4f}")
    
    # Print average cross-validation results
    print("\nAverage Cross-validation Results:")
    for metric in metrics:
        print(f"{metric.upper()}: {np.mean(metrics[metric]):.4f} ± {np.std(metrics[metric]):.4f}")
    
    # Ensemble predictions on test set
    test_pred_avg = np.mean(test_predictions, axis=0)
    test_pred_binary = (test_pred_avg > 0.5).astype(int)
    
    # Calculate final test metrics
    cm_test = confusion_matrix(y_test, test_pred_binary)
    
    print("\nFinal Test Set Results:")
    print(f"Accuracy: {accuracy_score(y_test, test_pred_binary):.4f}")
    print(f"Balanced Accuracy: {balanced_accuracy_score(y_test, test_pred_binary):.4f}")
    print(f"MCC: {matthews_corrcoef(y_test, test_pred_binary):.4f}")
    print(f"Sensitivity: {cm_test[1][1]/(cm_test[1][1]+cm_test[1][0]):.4f}")
    print(f"Specificity: {cm_test[0][0]/(cm_test[0][0]+cm_test[0][1]):.4f}")
    print("Confusion Matrix:")
    print(cm_test)
    
    return model

# %%
if __name__ == "__main__":
    model = train_and_evaluate()
# Out:
# Loading data...
# Loading ProtT5 embeddings...
# Aligning data...
#
# Training set distribution:
# label
# 1    4591
# 0    4257
# Name: count, dtype: int64
#
# Test set distribution:
# label
# 0    2497
# 1     240
# Name: count, dtype: int64
#
# Data shapes:
# X_train_seq: (8848, 33)
# X_train_struct: (8848, 1, 21)
# X_train_prot_t5: (8848, 1024)
# X_test_seq: (2737, 33)
# X_test_struct: (2737, 1, 21)
# X_test_prot_t5: (2737, 1024)
# y_train: (8848,)
# y_test: (2737,)
#
# Fold 1/5
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2024-12-11 19:14:53.501730: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-12-11 19:14:53.501754: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-12-11 19:14:53.501761: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-12-11 19:14:53.501776: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-11 19:14:53.501788: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/50
# 2024-12-11 19:14:54.950867: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 35s 132ms/step - accuracy: 0.5216 - loss: 8.2846 - val_accuracy: 0.5661 - val_loss: 5.8030 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 116ms/step - accuracy: 0.5396 - loss: 5.2550 - val_accuracy: 0.5847 - val_loss: 3.5910 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 117ms/step - accuracy: 0.5763 - loss: 3.3868 - val_accuracy: 0.6503 - val_loss: 2.4110 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 119ms/step - accuracy: 0.6187 - loss: 2.2303 - val_accuracy: 0.6503 - val_loss: 1.6851 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 122ms/step - accuracy: 0.6643 - loss: 1.5757 - val_accuracy: 0.6864 - val_loss: 1.2805 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 116ms/step - accuracy: 0.6751 - loss: 1.2198 - val_accuracy: 0.6904 - val_loss: 1.0595 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - accuracy: 0.6972 - loss: 1.0285 - val_accuracy: 0.6944 - val_loss: 0.9529 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 117ms/step - accuracy: 0.6865 - loss: 0.9483 - val_accuracy: 0.6661 - val_loss: 0.9368 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 116ms/step - accuracy: 0.6821 - loss: 0.9129 - val_accuracy: 0.7062 - val_loss: 0.8943 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 113ms/step - accuracy: 0.6970 - loss: 0.8872 - val_accuracy: 0.6243 - val_loss: 0.9273 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 122ms/step - accuracy: 0.7267 - loss: 0.8496 - val_accuracy: 0.6836 - val_loss: 0.8750 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 121ms/step - accuracy: 0.7324 - loss: 0.8301 - val_accuracy: 0.6791 - val_loss: 0.8458 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.7278 - loss: 0.8062 - val_accuracy: 0.7215 - val_loss: 0.8210 - learning_rate: 0.0010
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.7442 - loss: 0.7975 - val_accuracy: 0.7322 - val_loss: 0.7897 - learning_rate: 0.0010
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.7616 - loss: 0.7763 - val_accuracy: 0.6831 - val_loss: 0.8525 - learning_rate: 0.0010
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 127ms/step - accuracy: 0.7542 - loss: 0.7991 - val_accuracy: 0.7085 - val_loss: 0.8329 - learning_rate: 0.0010
# Epoch 17/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.7587 - loss: 0.7703 - val_accuracy: 0.7175 - val_loss: 0.8177 - learning_rate: 0.0010
# Epoch 18/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - accuracy: 0.7749 - loss: 0.7294 - val_accuracy: 0.7469 - val_loss: 0.7375 - learning_rate: 5.0000e-04
# Epoch 19/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 122ms/step - accuracy: 0.7881 - loss: 0.6781 - val_accuracy: 0.7345 - val_loss: 0.7295 - learning_rate: 5.0000e-04
# Epoch 20/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.7880 - loss: 0.6517 - val_accuracy: 0.7356 - val_loss: 0.7275 - learning_rate: 5.0000e-04
# Epoch 21/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 115ms/step - accuracy: 0.7945 - loss: 0.6509 - val_accuracy: 0.7542 - val_loss: 0.7146 - learning_rate: 5.0000e-04
# Epoch 22/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 115ms/step - accuracy: 0.8082 - loss: 0.6288 - val_accuracy: 0.7379 - val_loss: 0.7441 - learning_rate: 5.0000e-04
# Epoch 23/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 116ms/step - accuracy: 0.8000 - loss: 0.6574 - val_accuracy: 0.7407 - val_loss: 0.7270 - learning_rate: 5.0000e-04
# Epoch 24/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 115ms/step - accuracy: 0.8027 - loss: 0.6316 - val_accuracy: 0.7220 - val_loss: 0.7328 - learning_rate: 5.0000e-04
# Epoch 25/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 116ms/step - accuracy: 0.8163 - loss: 0.5966 - val_accuracy: 0.7379 - val_loss: 0.7065 - learning_rate: 2.5000e-04
# Epoch 26/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - accuracy: 0.8392 - loss: 0.5384 - val_accuracy: 0.7367 - val_loss: 0.6980 - learning_rate: 2.5000e-04
# Epoch 27/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 139ms/step - accuracy: 0.8335 - loss: 0.5382 - val_accuracy: 0.7305 - val_loss: 0.7063 - learning_rate: 2.5000e-04
# Epoch 28/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.8386 - loss: 0.5321 - val_accuracy: 0.7475 - val_loss: 0.7033 - learning_rate: 2.5000e-04
# Epoch 29/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 33s 151ms/step - accuracy: 0.8555 - loss: 0.5064 - val_accuracy: 0.7412 - val_loss: 0.7238 - learning_rate: 2.5000e-04
# Epoch 30/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 34s 155ms/step - accuracy: 0.8512 - loss: 0.5075 - val_accuracy: 0.7367 - val_loss: 0.7145 - learning_rate: 1.2500e-04
# Epoch 31/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 33s 150ms/step - accuracy: 0.8705 - loss: 0.4652 - val_accuracy: 0.7345 - val_loss: 0.7226 - learning_rate: 1.2500e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# Fold 1 Results:
# Accuracy: 0.7367
# Balanced Accuracy: 0.7372
# MCC: 0.4742
# Sensitivity: 0.7218
# Specificity: 0.7526
#
# Learned track weights for fold 1:
# Sequence weight: 0.4165
# Structure weight: 0.2633
# ProtT5 weight: 0.3201
#
# Fold 2/5
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 36s 137ms/step - accuracy: 0.5199 - loss: 8.2607 - val_accuracy: 0.5932 - val_loss: 5.5895 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - accuracy: 0.5503 - loss: 5.0293 - val_accuracy: 0.5746 - val_loss: 3.3429 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 127ms/step - accuracy: 0.5952 - loss: 2.9701 - val_accuracy: 0.6254 - val_loss: 2.0638 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.6535 - loss: 1.8823 - val_accuracy: 0.6565 - val_loss: 1.4458 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.6927 - loss: 1.3555 - val_accuracy: 0.7023 - val_loss: 1.1421 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 133ms/step - accuracy: 0.7113 - loss: 1.0952 - val_accuracy: 0.7062 - val_loss: 0.9985 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 127ms/step - accuracy: 0.7190 - loss: 0.9639 - val_accuracy: 0.6938 - val_loss: 0.9456 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 141ms/step - accuracy: 0.7266 - loss: 0.9002 - val_accuracy: 0.7107 - val_loss: 0.8888 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 138ms/step - accuracy: 0.7360 - loss: 0.8621 - val_accuracy: 0.6294 - val_loss: 0.9938 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 119ms/step - accuracy: 0.7381 - loss: 0.8683 - val_accuracy: 0.7271 - val_loss: 0.8461 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 119ms/step - accuracy: 0.7549 - loss: 0.8149 - val_accuracy: 0.7350 - val_loss: 0.8188 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 118ms/step - accuracy: 0.7624 - loss: 0.8018 - val_accuracy: 0.7446 - val_loss: 0.8208 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - accuracy: 0.7630 - loss: 0.7946 - val_accuracy: 0.7299 - val_loss: 0.8286 - learning_rate: 0.0010
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - accuracy: 0.7577 - loss: 0.7900 - val_accuracy: 0.7605 - val_loss: 0.7828 - learning_rate: 0.0010
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - accuracy: 0.7749 - loss: 0.7533 - val_accuracy: 0.7559 - val_loss: 0.7732 - learning_rate: 0.0010
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 128ms/step - accuracy: 0.7692 - loss: 0.7560 - val_accuracy: 0.7537 - val_loss: 0.7660 - learning_rate: 0.0010
# Epoch 17/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 35s 156ms/step - accuracy: 0.7779 - loss: 0.7520 - val_accuracy: 0.7384 - val_loss: 0.7815 - learning_rate: 0.0010
# Epoch 18/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 32s 146ms/step - accuracy: 0.7801 - loss: 0.7379 - val_accuracy: 0.7480 - val_loss: 0.7711 - learning_rate: 0.0010
# Epoch 19/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 140ms/step - accuracy: 0.7899 - loss: 0.7167 - val_accuracy: 0.7480 - val_loss: 0.7771 - learning_rate: 0.0010
# Epoch 20/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 127ms/step - accuracy: 0.8003 - loss: 0.7061 - val_accuracy: 0.7667 - val_loss: 0.7055 - learning_rate: 5.0000e-04
# Epoch 21/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 132ms/step - accuracy: 0.8121 - loss: 0.6342 - val_accuracy: 0.7746 - val_loss: 0.6995 - learning_rate: 5.0000e-04
# Epoch 22/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 33s 146ms/step - accuracy: 0.8160 - loss: 0.6393 - val_accuracy: 0.7554 - val_loss: 0.7139 - learning_rate: 5.0000e-04
# Epoch 23/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 140ms/step - accuracy: 0.8161 - loss: 0.6240 - val_accuracy: 0.7605 - val_loss: 0.7171 - learning_rate: 5.0000e-04
# Epoch 24/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.8217 - loss: 0.6252 - val_accuracy: 0.7684 - val_loss: 0.7058 - learning_rate: 5.0000e-04
# Epoch 25/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 142ms/step - accuracy: 0.8360 - loss: 0.5905 - val_accuracy: 0.7870 - val_loss: 0.6689 - learning_rate: 2.5000e-04
# Epoch 26/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 39s 176ms/step - accuracy: 0.8600 - loss: 0.5252 - val_accuracy: 0.7774 - val_loss: 0.6656 - learning_rate: 2.5000e-04
# Epoch 27/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 136ms/step - accuracy: 0.8627 - loss: 0.5173 - val_accuracy: 0.7780 - val_loss: 0.6734 - learning_rate: 2.5000e-04
# Epoch 28/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 34s 152ms/step - accuracy: 0.8667 - loss: 0.4975 - val_accuracy: 0.7763 - val_loss: 0.6790 - learning_rate: 2.5000e-04
# Epoch 29/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 139ms/step - accuracy: 0.8697 - loss: 0.4889 - val_accuracy: 0.7746 - val_loss: 0.6893 - learning_rate: 2.5000e-04
# Epoch 30/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - accuracy: 0.8757 - loss: 0.4742 - val_accuracy: 0.7701 - val_loss: 0.6877 - learning_rate: 1.2500e-04
# Epoch 31/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.8872 - loss: 0.4393 - val_accuracy: 0.7774 - val_loss: 0.6820 - learning_rate: 1.2500e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
#
# Fold 2 Results:
# Accuracy: 0.7774
# Balanced Accuracy: 0.7738
# MCC: 0.5525
# Sensitivity: 0.8301
# Specificity: 0.7174
#
# Learned track weights for fold 2:
# Sequence weight: 0.4657
# Structure weight: 0.2277
# ProtT5 weight: 0.3066
#
# Fold 3/5
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 46s 159ms/step - accuracy: 0.5232 - loss: 8.3212 - val_accuracy: 0.5237 - val_loss: 5.8365 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 128ms/step - accuracy: 0.5757 - loss: 5.2260 - val_accuracy: 0.5718 - val_loss: 3.5885 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 132ms/step - accuracy: 0.6133 - loss: 3.2174 - val_accuracy: 0.6345 - val_loss: 2.2765 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 132ms/step - accuracy: 0.6759 - loss: 2.0603 - val_accuracy: 0.6836 - val_loss: 1.5498 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.6818 - loss: 1.4558 - val_accuracy: 0.6864 - val_loss: 1.2184 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.6928 - loss: 1.2218 - val_accuracy: 0.6718 - val_loss: 1.0586 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - accuracy: 0.7009 - loss: 1.0110 - val_accuracy: 0.6915 - val_loss: 0.9230 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - accuracy: 0.7170 - loss: 0.9347 - val_accuracy: 0.7034 - val_loss: 0.9020 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - accuracy: 0.7238 - loss: 0.8942 - val_accuracy: 0.7062 - val_loss: 0.8843 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - accuracy: 0.7298 - loss: 0.8492 - val_accuracy: 0.7006 - val_loss: 0.8715 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 139ms/step - accuracy: 0.7409 - loss: 0.8312 - val_accuracy: 0.6062 - val_loss: 0.9400 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - accuracy: 0.7374 - loss: 0.8414 - val_accuracy: 0.7305 - val_loss: 0.8513 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 124ms/step - accuracy: 0.7551 - loss: 0.8130 - val_accuracy: 0.7367 - val_loss: 0.8338 - learning_rate: 0.0010
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 121ms/step - accuracy: 0.7532 - loss: 0.8130 - val_accuracy: 0.7254 - val_loss: 0.8335 - learning_rate: 0.0010
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 136ms/step - accuracy: 0.7580 - loss: 0.8075 - val_accuracy: 0.7169 - val_loss: 0.8788 - learning_rate: 0.0010
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 127ms/step - accuracy: 0.7695 - loss: 0.7954 - val_accuracy: 0.7000 - val_loss: 0.8171 - learning_rate: 0.0010
# Epoch 17/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - accuracy: 0.7515 - loss: 0.7690 - val_accuracy: 0.7350 - val_loss: 0.8292 - learning_rate: 0.0010
# Epoch 18/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - accuracy: 0.7674 - loss: 0.7462 - val_accuracy: 0.7311 - val_loss: 0.8289 - learning_rate: 0.0010
# Epoch 19/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.7550 - loss: 0.8117 - val_accuracy: 0.7379 - val_loss: 0.8074 - learning_rate: 0.0010
# Epoch 20/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 33s 147ms/step - accuracy: 0.7721 - loss: 0.7576 - val_accuracy: 0.7463 - val_loss: 0.7805 - learning_rate: 0.0010
# Epoch 21/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 32s 146ms/step - accuracy: 0.7749 - loss: 0.7490 - val_accuracy: 0.7367 - val_loss: 0.7772 - learning_rate: 0.0010
# Epoch 22/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 34s 152ms/step - accuracy: 0.7832 - loss: 0.7414 - val_accuracy: 0.7458 - val_loss: 0.7654 - learning_rate: 0.0010
# Epoch 23/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 140ms/step - accuracy: 0.7855 - loss: 0.7317 - val_accuracy: 0.7362 - val_loss: 0.8012 - learning_rate: 0.0010
# Epoch 24/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 136ms/step - accuracy: 0.7796 - loss: 0.7358 - val_accuracy: 0.7508 - val_loss: 0.7879 - learning_rate: 0.0010
# Epoch 25/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - accuracy: 0.7787 - loss: 0.7295 - val_accuracy: 0.7424 - val_loss: 0.7866 - learning_rate: 0.0010
# Epoch 26/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - accuracy: 0.7948 - loss: 0.6853 - val_accuracy: 0.7508 - val_loss: 0.7233 - learning_rate: 5.0000e-04
# Epoch 27/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 128ms/step - accuracy: 0.8082 - loss: 0.6280 - val_accuracy: 0.7424 - val_loss: 0.7426 - learning_rate: 5.0000e-04
# Epoch 28/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.8100 - loss: 0.6234 - val_accuracy: 0.7497 - val_loss: 0.7241 - learning_rate: 5.0000e-04
# Epoch 29/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 32s 146ms/step - accuracy: 0.8177 - loss: 0.6140 - val_accuracy: 0.7548 - val_loss: 0.7333 - learning_rate: 5.0000e-04
# Epoch 30/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 127ms/step - accuracy: 0.8301 - loss: 0.5794 - val_accuracy: 0.7599 - val_loss: 0.7084 - learning_rate: 2.5000e-04
# Epoch 31/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 32s 143ms/step - accuracy: 0.8509 - loss: 0.5334 - val_accuracy: 0.7605 - val_loss: 0.7083 - learning_rate: 2.5000e-04
# Epoch 32/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 137ms/step - accuracy: 0.8529 - loss: 0.5165 - val_accuracy: 0.7593 - val_loss: 0.6980 - learning_rate: 2.5000e-04
# Epoch 33/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 132ms/step - accuracy: 0.8543 - loss: 0.5151 - val_accuracy: 0.7531 - val_loss: 0.7129 - learning_rate: 2.5000e-04
# Epoch 34/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.8625 - loss: 0.5091 - val_accuracy: 0.7621 - val_loss: 0.7233 - learning_rate: 2.5000e-04
# Epoch 35/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 128ms/step - accuracy: 0.8589 - loss: 0.4987 - val_accuracy: 0.7548 - val_loss: 0.7259 - learning_rate: 2.5000e-04
# Epoch 36/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - accuracy: 0.8668 - loss: 0.4801 - val_accuracy: 0.7514 - val_loss: 0.7273 - learning_rate: 1.2500e-04
# Epoch 37/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - accuracy: 0.8860 - loss: 0.4332 - val_accuracy: 0.7616 - val_loss: 0.7247 - learning_rate: 1.2500e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#
# Fold 3 Results:
# Accuracy: 0.7593
# Balanced Accuracy: 0.7572
# MCC: 0.5229
# Sensitivity: 0.8412
# Specificity: 0.6732
#
# Learned track weights for fold 3:
# Sequence weight: 0.4302
# Structure weight: 0.2602
# ProtT5 weight: 0.3096
#
# Fold 4/5
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 38s 141ms/step - accuracy: 0.5061 - loss: 8.3883 - val_accuracy: 0.5003 - val_loss: 5.9767 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.5417 - loss: 5.4378 - val_accuracy: 0.5608 - val_loss: 3.7218 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 139ms/step - accuracy: 0.5684 - loss: 3.3565 - val_accuracy: 0.5953 - val_loss: 2.3522 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 140ms/step - accuracy: 0.5989 - loss: 2.1440 - val_accuracy: 0.6252 - val_loss: 1.5816 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 141ms/step - accuracy: 0.6362 - loss: 1.4758 - val_accuracy: 0.6682 - val_loss: 1.2047 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.6638 - loss: 1.1668 - val_accuracy: 0.6885 - val_loss: 1.0181 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - accuracy: 0.6842 - loss: 1.0225 - val_accuracy: 0.6936 - val_loss: 0.9269 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 129ms/step - accuracy: 0.6930 - loss: 0.9337 - val_accuracy: 0.6868 - val_loss: 0.8772 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 140ms/step - accuracy: 0.7085 - loss: 0.8769 - val_accuracy: 0.7060 - val_loss: 0.8809 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 136ms/step - accuracy: 0.6901 - loss: 0.8812 - val_accuracy: 0.7123 - val_loss: 0.8407 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 32s 143ms/step - accuracy: 0.7000 - loss: 0.8583 - val_accuracy: 0.7021 - val_loss: 0.8535 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 36s 163ms/step - accuracy: 0.7077 - loss: 0.8675 - val_accuracy: 0.7117 - val_loss: 0.8591 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 129ms/step - accuracy: 0.7149 - loss: 0.8559 - val_accuracy: 0.7162 - val_loss: 0.8441 - learning_rate: 0.0010
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.7473 - loss: 0.8038 - val_accuracy: 0.7445 - val_loss: 0.7492 - learning_rate: 5.0000e-04
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 119ms/step - accuracy: 0.7538 - loss: 0.7549 - val_accuracy: 0.7434 - val_loss: 0.7565 - learning_rate: 5.0000e-04
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 119ms/step - accuracy: 0.7605 - loss: 0.7489 - val_accuracy: 0.7196 - val_loss: 0.7619 - learning_rate: 5.0000e-04
# Epoch 17/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 118ms/step - accuracy: 0.7650 - loss: 0.7379 - val_accuracy: 0.7484 - val_loss: 0.7394 - learning_rate: 5.0000e-04
# Epoch 18/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - accuracy: 0.7755 - loss: 0.7244 - val_accuracy: 0.7592 - val_loss: 0.7282 - learning_rate: 5.0000e-04
# Epoch 19/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 129ms/step - accuracy: 0.7869 - loss: 0.6982 - val_accuracy: 0.7366 - val_loss: 0.7376 - learning_rate: 5.0000e-04
# Epoch 20/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - accuracy: 0.7835 - loss: 0.6943 - val_accuracy: 0.7462 - val_loss: 0.7342 - learning_rate: 5.0000e-04
# Epoch 21/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 132ms/step - accuracy: 0.8003 - loss: 0.6772 - val_accuracy: 0.7270 - val_loss: 0.7723 - learning_rate: 5.0000e-04
# Epoch 22/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 132ms/step - accuracy: 0.8012 - loss: 0.6574 - val_accuracy: 0.7518 - val_loss: 0.6893 - learning_rate: 2.5000e-04
# Epoch 23/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 32s 145ms/step - accuracy: 0.8219 - loss: 0.5980 - val_accuracy: 0.7569 - val_loss: 0.6777 - learning_rate: 2.5000e-04
# Epoch 24/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 37s 165ms/step - accuracy: 0.8314 - loss: 0.5846 - val_accuracy: 0.7558 - val_loss: 0.6835 - learning_rate: 2.5000e-04
# Epoch 25/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - accuracy: 0.8328 - loss: 0.5769 - val_accuracy: 0.7541 - val_loss: 0.6819 - learning_rate: 2.5000e-04
# Epoch 26/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 121ms/step - accuracy: 0.8337 - loss: 0.5702 - val_accuracy: 0.7654 - val_loss: 0.6907 - learning_rate: 2.5000e-04
# Epoch 27/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 121ms/step - accuracy: 0.8459 - loss: 0.5455 - val_accuracy: 0.7609 - val_loss: 0.6706 - learning_rate: 1.2500e-04
# Epoch 28/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 119ms/step - accuracy: 0.8586 - loss: 0.5044 - val_accuracy: 0.7665 - val_loss: 0.6625 - learning_rate: 1.2500e-04
# Epoch 29/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.8717 - loss: 0.4896 - val_accuracy: 0.7705 - val_loss: 0.6581 - learning_rate: 1.2500e-04
# Epoch 30/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 119ms/step - accuracy: 0.8726 - loss: 0.4744 - val_accuracy: 0.7575 - val_loss: 0.6757 - learning_rate: 1.2500e-04
# Epoch 31/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 119ms/step - accuracy: 0.8784 - loss: 0.4615 - val_accuracy: 0.7631 - val_loss: 0.6829 - learning_rate: 1.2500e-04
# Epoch 32/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 118ms/step - accuracy: 0.8810 - loss: 0.4543 - val_accuracy: 0.7654 - val_loss: 0.6793 - learning_rate: 1.2500e-04
# Epoch 33/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 118ms/step - accuracy: 0.8858 - loss: 0.4333 - val_accuracy: 0.7660 - val_loss: 0.6826 - learning_rate: 6.2500e-05
# Epoch 34/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.8971 - loss: 0.4112 - val_accuracy: 0.7688 - val_loss: 0.6784 - learning_rate: 6.2500e-05
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#
# Fold 4 Results:
# Accuracy: 0.7705
# Balanced Accuracy: 0.7690
# MCC: 0.5411
# Sensitivity: 0.8158
# Specificity: 0.7223
#
# Learned track weights for fold 4:
# Sequence weight: 0.4068
# Structure weight: 0.2612
# ProtT5 weight: 0.3320
#
# Fold 5/5
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 35s 127ms/step - accuracy: 0.5129 - loss: 8.4794 - val_accuracy: 0.5314 - val_loss: 6.2474 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 132ms/step - accuracy: 0.5551 - loss: 5.7739 - val_accuracy: 0.5806 - val_loss: 4.1253 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.5938 - loss: 3.7586 - val_accuracy: 0.6032 - val_loss: 2.7140 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 34s 151ms/step - accuracy: 0.6195 - loss: 2.4704 - val_accuracy: 0.6049 - val_loss: 1.8629 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 129ms/step - accuracy: 0.6526 - loss: 1.7202 - val_accuracy: 0.6286 - val_loss: 1.4000 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 141ms/step - accuracy: 0.6754 - loss: 1.3027 - val_accuracy: 0.6637 - val_loss: 1.1448 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - accuracy: 0.6896 - loss: 1.0989 - val_accuracy: 0.6761 - val_loss: 1.0213 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.6887 - loss: 0.9919 - val_accuracy: 0.6998 - val_loss: 0.9297 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.7073 - loss: 0.9044 - val_accuracy: 0.6964 - val_loss: 0.8902 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 139ms/step - accuracy: 0.7182 - loss: 0.8793 - val_accuracy: 0.7298 - val_loss: 0.8380 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 137ms/step - accuracy: 0.7318 - loss: 0.8352 - val_accuracy: 0.7191 - val_loss: 0.8451 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 129ms/step - accuracy: 0.7265 - loss: 0.8487 - val_accuracy: 0.7405 - val_loss: 0.8271 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 129ms/step - accuracy: 0.7395 - loss: 0.8175 - val_accuracy: 0.7174 - val_loss: 0.8023 - learning_rate: 0.0010
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - accuracy: 0.7526 - loss: 0.7820 - val_accuracy: 0.7326 - val_loss: 0.7812 - learning_rate: 0.0010
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.7508 - loss: 0.7947 - val_accuracy: 0.7309 - val_loss: 0.7971 - learning_rate: 0.0010
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 129ms/step - accuracy: 0.7596 - loss: 0.7693 - val_accuracy: 0.7055 - val_loss: 0.7830 - learning_rate: 0.0010
# Epoch 17/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - accuracy: 0.7624 - loss: 0.7479 - val_accuracy: 0.7128 - val_loss: 0.7734 - learning_rate: 0.0010
# Epoch 18/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.7675 - loss: 0.7308 - val_accuracy: 0.6812 - val_loss: 0.8034 - learning_rate: 0.0010
# Epoch 19/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.7685 - loss: 0.7325 - val_accuracy: 0.6959 - val_loss: 0.8043 - learning_rate: 0.0010
# Epoch 20/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.7685 - loss: 0.7349 - val_accuracy: 0.7569 - val_loss: 0.7789 - learning_rate: 0.0010
# Epoch 21/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.7866 - loss: 0.7134 - val_accuracy: 0.7671 - val_loss: 0.6915 - learning_rate: 5.0000e-04
# Epoch 22/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 121ms/step - accuracy: 0.7988 - loss: 0.6535 - val_accuracy: 0.7507 - val_loss: 0.6957 - learning_rate: 5.0000e-04
# Epoch 23/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.8000 - loss: 0.6399 - val_accuracy: 0.7637 - val_loss: 0.6840 - learning_rate: 5.0000e-04
# Epoch 24/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 119ms/step - accuracy: 0.8151 - loss: 0.6158 - val_accuracy: 0.7507 - val_loss: 0.7152 - learning_rate: 5.0000e-04
# Epoch 25/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.8093 - loss: 0.6273 - val_accuracy: 0.7671 - val_loss: 0.6877 - learning_rate: 5.0000e-04
# Epoch 26/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.8197 - loss: 0.6135 - val_accuracy: 0.7592 - val_loss: 0.6921 - learning_rate: 5.0000e-04
# Epoch 27/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.8254 - loss: 0.6001 - val_accuracy: 0.7773 - val_loss: 0.6490 - learning_rate: 2.5000e-04
# Epoch 28/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 121ms/step - accuracy: 0.8344 - loss: 0.5516 - val_accuracy: 0.7778 - val_loss: 0.6460 - learning_rate: 2.5000e-04
# Epoch 29/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.8454 - loss: 0.5288 - val_accuracy: 0.7637 - val_loss: 0.6660 - learning_rate: 2.5000e-04
# Epoch 30/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.8499 - loss: 0.5216 - val_accuracy: 0.7581 - val_loss: 0.6760 - learning_rate: 2.5000e-04
# Epoch 31/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 121ms/step - accuracy: 0.8516 - loss: 0.5068 - val_accuracy: 0.7682 - val_loss: 0.6604 - learning_rate: 2.5000e-04
# Epoch 32/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 118ms/step - accuracy: 0.8608 - loss: 0.4844 - val_accuracy: 0.7761 - val_loss: 0.6463 - learning_rate: 1.2500e-04
# Epoch 33/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 119ms/step - accuracy: 0.8725 - loss: 0.4593 - val_accuracy: 0.7795 - val_loss: 0.6444 - learning_rate: 1.2500e-04
# Epoch 34/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.8770 - loss: 0.4374 - val_accuracy: 0.7722 - val_loss: 0.6486 - learning_rate: 1.2500e-04
# Epoch 35/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 121ms/step - accuracy: 0.8849 - loss: 0.4258 - val_accuracy: 0.7812 - val_loss: 0.6627 - learning_rate: 1.2500e-04
# Epoch 36/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 118ms/step - accuracy: 0.8734 - loss: 0.4251 - val_accuracy: 0.7790 - val_loss: 0.6581 - learning_rate: 1.2500e-04
# Epoch 37/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.8877 - loss: 0.4090 - val_accuracy: 0.7761 - val_loss: 0.6585 - learning_rate: 6.2500e-05
# Epoch 38/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 121ms/step - accuracy: 0.8921 - loss: 0.3893 - val_accuracy: 0.7790 - val_loss: 0.6618 - learning_rate: 6.2500e-05
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# Fold 5 Results:
# Accuracy: 0.7795
# Balanced Accuracy: 0.7768
# MCC: 0.5612
# Sensitivity: 0.8506
# Specificity: 0.7031
#
# Learned track weights for fold 5:
# Sequence weight: 0.4277
# Structure weight: 0.2689
# ProtT5 weight: 0.3034
#
# Average track weights across folds:
# Sequence weight: 0.4294 ± 0.0200
# Structure weight: 0.2563 ± 0.0146
# ProtT5 weight: 0.3143 ± 0.0105
#
# Average Cross-validation Results:
# ACC: 0.7647 ± 0.0157
# BALANCED_ACC: 0.7628 ± 0.0144
# MCC: 0.5304 ± 0.0309
# SN: 0.8119 ± 0.0465
# SP: 0.7137 ± 0.0259
#
# Final Test Set Results:
# Accuracy: 0.7242
# Balanced Accuracy: 0.7961
# MCC: 0.3528
# Sensitivity: 0.8833
# Specificity: 0.7089
# Confusion Matrix:
# [[1770  727]
#  [  28  212]]
