# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, matthews_corrcoef, accuracy_score, balanced_accuracy_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
import random

# %%
# Set random seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.keras.utils.set_random_seed(SEED)  # This sets all random seeds in keras
tf.config.experimental.enable_op_determinism()  # For complete reproducibility

# %%
def prepare_structure_data(df):
    """Enhanced feature preparation with better normalization"""
    
    # Normalize angles to their circular nature
    def normalize_angles(angle_array):
        angle_rad = np.pi * angle_array / 180.0
        return np.stack([np.sin(angle_rad), np.cos(angle_rad)], axis=-1)
    
    # Process each feature type
    features_list = []
    
    # 1. Process angles (phi, psi, omega, tau)
    angles = ['phi', 'psi', 'omega', 'tau']
    for angle in angles:
        # Convert string to array
        angle_arrays = np.array([np.array(eval(x)) for x in df[angle]])
        # Get sin/cos representations
        angle_features = normalize_angles(angle_arrays)
        features_list.append(angle_features)
    
    # 2. Process SASA
    sasa_arrays = np.array([np.array(eval(x)) for x in df['sasa']])
    scaler = RobustScaler()
    sasa_flat = sasa_arrays.reshape(-1, 1)
    sasa_scaled = scaler.fit_transform(sasa_flat).reshape(sasa_arrays.shape)
    features_list.append(sasa_scaled[..., np.newaxis])
    
    # 3. Process secondary structure
    ss_arrays = np.array([list(seq) for seq in df['ss']])
    ss_encoded = np.zeros((len(ss_arrays), ss_arrays.shape[1], 3))
    ss_map = {'H': 0, 'E': 1, 'L': 2}
    for i in range(len(ss_arrays)):
        for j in range(len(ss_arrays[i])):
            ss_encoded[i, j, ss_map[ss_arrays[i, j]]] = 1
    features_list.append(ss_encoded)
    
    # Combine all features
    features = np.concatenate(features_list, axis=-1)
    
    return features

# %%
def create_structure_model(window_size=33, n_features=12):
    """Model with stronger regularization to prevent overfitting"""
    
    inputs = tf.keras.layers.Input(shape=(window_size, n_features))
    
    # Initial regularization
    x = tf.keras.layers.BatchNormalization()(inputs)
    x = tf.keras.layers.Dropout(0.2)(x)  # Add initial dropout
    
    # Simplified convolutional layers with L2 regularization
    conv1 = tf.keras.layers.Conv1D(
        32, 3, 
        padding='same', 
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(x)
    
    conv2 = tf.keras.layers.Conv1D(
        32, 5, 
        padding='same', 
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(x)
    
    # Combine and normalize
    x = tf.keras.layers.Concatenate()([conv1, conv2])
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    
    # Simplified attention mechanism
    attention = tf.keras.layers.MultiHeadAttention(
        num_heads=2,  # Reduced number of heads
        key_dim=16,   # Reduced dimension
        kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(x, x)
    
    x = tf.keras.layers.Add()([x, attention])
    x = tf.keras.layers.LayerNormalization()(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    
    # Focus on central residue with context
    central_pos = window_size // 2
    x = tf.keras.layers.Lambda(
        lambda x: x[:, central_pos-1:central_pos+2, :]
    )(x)
    
    x = tf.keras.layers.Flatten()(x)
    
    # Simplified dense layers with strong regularization
    x = tf.keras.layers.Dense(
        64, 
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    
    x = tf.keras.layers.Dense(
        32, 
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    
    # Output layer
    outputs = tf.keras.layers.Dense(
        1, 
        activation='sigmoid',
        kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(x)
    
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, matthews_corrcoef, accuracy_score, balanced_accuracy_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
import random

# Set random seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.keras.utils.set_random_seed(SEED)
tf.config.experimental.enable_op_determinism()

def prepare_structure_data(df):
    """Enhanced feature preparation with better normalization"""
    
    # Normalize angles to their circular nature
    def normalize_angles(angle_array):
        angle_rad = np.pi * angle_array / 180.0
        return np.stack([np.sin(angle_rad), np.cos(angle_rad)], axis=-1)
    
    # Process each feature type
    features_list = []
    
    # 1. Process angles (phi, psi, omega, tau)
    angles = ['phi', 'psi', 'omega', 'tau']
    for angle in angles:
        # Convert string to array
        angle_arrays = np.array([np.array(eval(x)) for x in df[angle]])
        # Get sin/cos representations
        angle_features = normalize_angles(angle_arrays)
        features_list.append(angle_features)
    
    # 2. Process SASA
    sasa_arrays = np.array([np.array(eval(x)) for x in df['sasa']])
    scaler = RobustScaler()
    sasa_flat = sasa_arrays.reshape(-1, 1)
    sasa_scaled = scaler.fit_transform(sasa_flat).reshape(sasa_arrays.shape)
    features_list.append(sasa_scaled[..., np.newaxis])
    
    # 3. Process secondary structure
    ss_arrays = np.array([list(seq) for seq in df['ss']])
    ss_encoded = np.zeros((len(ss_arrays), ss_arrays.shape[1], 3))
    ss_map = {'H': 0, 'E': 1, 'L': 2}
    for i in range(len(ss_arrays)):
        for j in range(len(ss_arrays[i])):
            ss_encoded[i, j, ss_map[ss_arrays[i, j]]] = 1
    features_list.append(ss_encoded)
    
    # Combine all features
    features = np.concatenate(features_list, axis=-1)
    
    return features

def create_structure_model(window_size=33, n_features=12):
    """Enhanced model architecture with multi-scale feature extraction"""
    
    inputs = tf.keras.layers.Input(shape=(window_size, n_features))
    
    # Initial feature processing
    x = tf.keras.layers.BatchNormalization()(inputs)
    
    # Multi-scale convolutions
    conv1 = tf.keras.layers.Conv1D(32, 3, padding='same', activation='relu')(x)
    conv3 = tf.keras.layers.Conv1D(32, 5, padding='same', activation='relu')(x)
    conv5 = tf.keras.layers.Conv1D(32, 7, padding='same', activation='relu')(x)
    
    # Combine multi-scale features
    x = tf.keras.layers.Concatenate()([conv1, conv3, conv5])
    x = tf.keras.layers.BatchNormalization()(x)
    
    # Self-attention layer
    attention = tf.keras.layers.MultiHeadAttention(
        num_heads=4, key_dim=32
    )(x, x)
    x = tf.keras.layers.Add()([x, attention])
    x = tf.keras.layers.LayerNormalization()(x)
    
    # Focus on central residue and context
    central_pos = window_size // 2
    x = tf.keras.layers.Lambda(
        lambda x: x[:, central_pos-2:central_pos+3, :]
    )(x)
    
    # Final feature processing
    x = tf.keras.layers.Flatten()(x)
    
    # Dense layers with skip connections
    x1 = tf.keras.layers.Dense(128, activation='relu')(x)
    x1 = tf.keras.layers.BatchNormalization()(x1)
    x1 = tf.keras.layers.Dropout(0.3)(x1)
    
    x2 = tf.keras.layers.Dense(128)(x1)
    x2 = tf.keras.layers.Add()([x1, x2])
    x2 = tf.keras.layers.Activation('relu')(x2)
    x2 = tf.keras.layers.BatchNormalization()(x2)
    x2 = tf.keras.layers.Dropout(0.3)(x2)
    
    # Output
    outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x2)
    
    return tf.keras.Model(inputs=inputs, outputs=outputs)

def train_and_evaluate():
    """Main training and evaluation function"""
    
    # Load data
    print("Loading data...")
    train_df = pd.read_csv("processed_data_train_after.csv")
    test_df = pd.read_csv("processed_data_test_after.csv")
    
    # Remove sequences contains '-'
    train_df = train_df[~train_df['sequence'].str.contains('-')]
    test_df = test_df[~test_df['sequence'].str.contains('-')]
    
    # Shuffle data
    train_df = train_df.sample(frac=1, random_state=SEED).reset_index(drop=True)
    test_df = test_df.sample(frac=1, random_state=SEED).reset_index(drop=True)
    
    # Print class distribution
    print("\nTraining set distribution:")
    print(train_df['label'].value_counts())
    print("\nTest set distribution:")
    print(test_df['label'].value_counts())
    
    # Prepare data
    print("\nPreparing structure data...")
    X_train = prepare_structure_data(train_df)
    X_test = prepare_structure_data(test_df)
    
    y_train = train_df['label'].values
    y_test = test_df['label'].values
    
    print(f"\nTraining data shape: {X_train.shape}")
    print(f"Test data shape: {X_test.shape}")
    
    # Calculate class weights
    total = len(y_train)
    pos = np.sum(y_train == 1)
    neg = np.sum(y_train == 0)
    class_weights = {
        0: total / (2 * neg),
        1: total / (2 * pos)
    }
    print("\nClass weights:", class_weights)
    
    # Initialize cross-validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
    metrics = {'acc': [], 'balanced_acc': [], 'mcc': [], 'sn': [], 'sp': []}
    test_predictions = []
    
    # Cross-validation loop
    for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train), 1):
        print(f"\nFold {fold}/5")
        
        # Create callbacks
        early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=5,          # Reduced patience
            restore_best_weights=True
        )
        
        lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,         # More aggressive reduction
            patience=3,         # Reduced patience
            min_lr=1e-6
        )
        
        # Create and compile model
        model = create_structure_model(
            window_size=X_train.shape[1],
            n_features=X_train.shape[2]
        )
        
        model.compile(
            optimizer=tf.keras.optimizers.Adam(
                learning_rate=5e-4,    # Lower initial learning rate
                clipnorm=1.0
            ),
            loss='binary_crossentropy',
            metrics=['accuracy']
        )
        
        # Train model
        history = model.fit(
            X_train[train_idx], y_train[train_idx],
            batch_size=64,          # Increased batch size
            epochs=50,              # Reduced max epochs
            validation_data=(X_train[val_idx], y_train[val_idx]),
            callbacks=[early_stopping, lr_scheduler],
            class_weight=class_weights,
            verbose=1
        )
        
        # Plot training history
        plt.figure(figsize=(10, 6))
        plt.plot(history.history['accuracy'], label='Train Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title(f'Model Accuracy - Fold {fold}')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()
        plt.show()
        
        # Evaluate on validation set
        y_pred = model.predict(X_train[val_idx])
        y_pred_binary = (y_pred > 0.5).astype(int)
        
        # Calculate metrics
        cm = confusion_matrix(y_train[val_idx], y_pred_binary)
        metrics['acc'].append(accuracy_score(y_train[val_idx], y_pred_binary))
        metrics['balanced_acc'].append(balanced_accuracy_score(y_train[val_idx], y_pred_binary))
        metrics['mcc'].append(matthews_corrcoef(y_train[val_idx], y_pred_binary))
        metrics['sn'].append(cm[1][1]/(cm[1][1]+cm[1][0]))  # Sensitivity
        metrics['sp'].append(cm[0][0]/(cm[0][0]+cm[0][1]))  # Specificity
        
        # Predict on test set
        test_pred = model.predict(X_test)
        test_predictions.append(test_pred)
        
        # Print fold results
        print(f"\nFold {fold} Results:")
        print(f"Accuracy: {metrics['acc'][-1]:.4f}")
        print(f"Balanced Accuracy: {metrics['balanced_acc'][-1]:.4f}")
        print(f"MCC: {metrics['mcc'][-1]:.4f}")
        print(f"Sensitivity: {metrics['sn'][-1]:.4f}")
        print(f"Specificity: {metrics['sp'][-1]:.4f}")
    
    # Print average cross-validation results
    print("\nAverage Cross-validation Results:")
    for metric in metrics:
        print(f"{metric.upper()}: {np.mean(metrics[metric]):.4f} ± {np.std(metrics[metric]):.4f}")
    
    # Ensemble predictions on test set
    test_pred_avg = np.mean(test_predictions, axis=0)
    test_pred_binary = (test_pred_avg > 0.5).astype(int)
    
    # Calculate final test metrics
    cm_test = confusion_matrix(y_test, test_pred_binary)
    
    print("\nFinal Test Set Results:")
    print(f"Accuracy: {accuracy_score(y_test, test_pred_binary):.4f}")
    print(f"Balanced Accuracy: {balanced_accuracy_score(y_test, test_pred_binary):.4f}")
    print(f"MCC: {matthews_corrcoef(y_test, test_pred_binary):.4f}")
    print(f"Sensitivity: {cm_test[1][1]/(cm_test[1][1]+cm_test[1][0]):.4f}")
    print(f"Specificity: {cm_test[0][0]/(cm_test[0][0]+cm_test[0][1]):.4f}")
    print("Confusion Matrix:")
    print(cm_test)
    
    return model

# %%
if __name__ == "__main__":
    model = train_and_evaluate()
# Out:
# Loading data...
#
# Training set distribution:
# label
# 1    4113
# 0    3878
# Name: count, dtype: int64
#
# Test set distribution:
# label
# 0    2251
# 1     215
# Name: count, dtype: int64
#
# Preparing structure data...
#
# Training data shape: (7991, 33, 12)
# Test data shape: (2466, 33, 12)
#
# Class weights: {0: 1.030299123259412, 1: 0.9714320447362023}
#
# Fold 1/5
# 2024-12-02 21:10:07.707024: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-12-02 21:10:07.707044: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-12-02 21:10:07.707050: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-12-02 21:10:07.707325: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-02 21:10:07.707336: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/50
# 2024-12-02 21:10:09.026185: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 65ms/step - accuracy: 0.5374 - loss: 0.8793 - val_accuracy: 0.5679 - val_loss: 0.7001 - learning_rate: 5.0000e-04
# Epoch 2/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.5655 - loss: 0.7587 - val_accuracy: 0.5897 - val_loss: 0.6867 - learning_rate: 5.0000e-04
# Epoch 3/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.5984 - loss: 0.7134 - val_accuracy: 0.5904 - val_loss: 0.6915 - learning_rate: 5.0000e-04
# Epoch 4/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.5999 - loss: 0.6968 - val_accuracy: 0.5872 - val_loss: 0.6904 - learning_rate: 5.0000e-04
# Epoch 5/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.6269 - loss: 0.6691 - val_accuracy: 0.5847 - val_loss: 0.6880 - learning_rate: 5.0000e-04
# Epoch 6/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.6544 - loss: 0.6273 - val_accuracy: 0.5766 - val_loss: 0.6905 - learning_rate: 1.0000e-04
# Epoch 7/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.6454 - loss: 0.6385 - val_accuracy: 0.5785 - val_loss: 0.6920 - learning_rate: 1.0000e-04
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
#
# Fold 1 Results:
# Accuracy: 0.5897
# Balanced Accuracy: 0.5862
# MCC: 0.1750
# Sensitivity: 0.6711
# Specificity: 0.5013
#
# Fold 2/5
# Epoch 1/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 64ms/step - accuracy: 0.5218 - loss: 0.8833 - val_accuracy: 0.5632 - val_loss: 0.7113 - learning_rate: 5.0000e-04
# Epoch 2/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.5753 - loss: 0.7325 - val_accuracy: 0.5857 - val_loss: 0.6922 - learning_rate: 5.0000e-04
# Epoch 3/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.6017 - loss: 0.6912 - val_accuracy: 0.5864 - val_loss: 0.6946 - learning_rate: 5.0000e-04
# Epoch 4/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.6004 - loss: 0.6800 - val_accuracy: 0.5945 - val_loss: 0.6891 - learning_rate: 5.0000e-04
# Epoch 5/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.6274 - loss: 0.6597 - val_accuracy: 0.5914 - val_loss: 0.6794 - learning_rate: 5.0000e-04
# Epoch 6/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.6464 - loss: 0.6331 - val_accuracy: 0.5976 - val_loss: 0.6782 - learning_rate: 5.0000e-04
# Epoch 7/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.6496 - loss: 0.6251 - val_accuracy: 0.5995 - val_loss: 0.6838 - learning_rate: 5.0000e-04
# Epoch 8/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.6611 - loss: 0.6107 - val_accuracy: 0.5945 - val_loss: 0.6908 - learning_rate: 5.0000e-04
# Epoch 9/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.6844 - loss: 0.5904 - val_accuracy: 0.5964 - val_loss: 0.6906 - learning_rate: 5.0000e-04
# Epoch 10/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.7004 - loss: 0.5627 - val_accuracy: 0.6008 - val_loss: 0.6842 - learning_rate: 1.0000e-04
# Epoch 11/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.7036 - loss: 0.5546 - val_accuracy: 0.6089 - val_loss: 0.6844 - learning_rate: 1.0000e-04
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 2 Results:
# Accuracy: 0.5976
# Balanced Accuracy: 0.5972
# MCC: 0.1950
# Sensitivity: 0.6349
# Specificity: 0.5595
#
# Fold 3/5
# Epoch 1/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - accuracy: 0.5305 - loss: 0.8839 - val_accuracy: 0.5720 - val_loss: 0.7041 - learning_rate: 5.0000e-04
# Epoch 2/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.5696 - loss: 0.7494 - val_accuracy: 0.5801 - val_loss: 0.6995 - learning_rate: 5.0000e-04
# Epoch 3/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.5938 - loss: 0.7087 - val_accuracy: 0.5876 - val_loss: 0.6883 - learning_rate: 5.0000e-04
# Epoch 4/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.6011 - loss: 0.6918 - val_accuracy: 0.5757 - val_loss: 0.6929 - learning_rate: 5.0000e-04
# Epoch 5/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.6238 - loss: 0.6576 - val_accuracy: 0.5976 - val_loss: 0.6848 - learning_rate: 5.0000e-04
# Epoch 6/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.6371 - loss: 0.6440 - val_accuracy: 0.5970 - val_loss: 0.6915 - learning_rate: 5.0000e-04
# Epoch 7/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.6545 - loss: 0.6320 - val_accuracy: 0.5939 - val_loss: 0.6961 - learning_rate: 5.0000e-04
# Epoch 8/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.6608 - loss: 0.6225 - val_accuracy: 0.5951 - val_loss: 0.6949 - learning_rate: 5.0000e-04
# Epoch 9/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.6872 - loss: 0.5885 - val_accuracy: 0.5945 - val_loss: 0.6920 - learning_rate: 1.0000e-04
# Epoch 10/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.6978 - loss: 0.5687 - val_accuracy: 0.5989 - val_loss: 0.6928 - learning_rate: 1.0000e-04
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
#
# Fold 3 Results:
# Accuracy: 0.5976
# Balanced Accuracy: 0.5987
# MCC: 0.1972
# Sensitivity: 0.5781
# Specificity: 0.6192
#
# Fold 4/5
# Epoch 1/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step - accuracy: 0.5330 - loss: 0.8718 - val_accuracy: 0.5469 - val_loss: 0.7409 - learning_rate: 5.0000e-04
# Epoch 2/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.5767 - loss: 0.7486 - val_accuracy: 0.5782 - val_loss: 0.6879 - learning_rate: 5.0000e-04
# Epoch 3/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.5857 - loss: 0.7075 - val_accuracy: 0.5839 - val_loss: 0.6763 - learning_rate: 5.0000e-04
# Epoch 4/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.6161 - loss: 0.6837 - val_accuracy: 0.5995 - val_loss: 0.6700 - learning_rate: 5.0000e-04
# Epoch 5/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.6291 - loss: 0.6552 - val_accuracy: 0.6089 - val_loss: 0.6663 - learning_rate: 5.0000e-04
# Epoch 6/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.6553 - loss: 0.6255 - val_accuracy: 0.6020 - val_loss: 0.6737 - learning_rate: 5.0000e-04
# Epoch 7/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.6624 - loss: 0.6156 - val_accuracy: 0.6089 - val_loss: 0.6731 - learning_rate: 5.0000e-04
# Epoch 8/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.6659 - loss: 0.6097 - val_accuracy: 0.6151 - val_loss: 0.6732 - learning_rate: 5.0000e-04
# Epoch 9/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.6820 - loss: 0.5828 - val_accuracy: 0.6170 - val_loss: 0.6746 - learning_rate: 1.0000e-04
# Epoch 10/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.6967 - loss: 0.5666 - val_accuracy: 0.6189 - val_loss: 0.6769 - learning_rate: 1.0000e-04
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 4 Results:
# Accuracy: 0.6089
# Balanced Accuracy: 0.6094
# MCC: 0.2224
# Sensitivity: 0.6990
# Specificity: 0.5199
#
# Fold 5/5
# Epoch 1/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step - accuracy: 0.5242 - loss: 0.8963 - val_accuracy: 0.5607 - val_loss: 0.7031 - learning_rate: 5.0000e-04
# Epoch 2/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.5681 - loss: 0.7698 - val_accuracy: 0.6033 - val_loss: 0.6776 - learning_rate: 5.0000e-04
# Epoch 3/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.5878 - loss: 0.7254 - val_accuracy: 0.6014 - val_loss: 0.6714 - learning_rate: 5.0000e-04
# Epoch 4/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.6035 - loss: 0.6863 - val_accuracy: 0.5982 - val_loss: 0.6706 - learning_rate: 5.0000e-04
# Epoch 5/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.6260 - loss: 0.6660 - val_accuracy: 0.6108 - val_loss: 0.6700 - learning_rate: 5.0000e-04
# Epoch 6/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.6401 - loss: 0.6507 - val_accuracy: 0.5989 - val_loss: 0.6728 - learning_rate: 5.0000e-04
# Epoch 7/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.6521 - loss: 0.6324 - val_accuracy: 0.6101 - val_loss: 0.6711 - learning_rate: 5.0000e-04
# Epoch 8/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.6504 - loss: 0.6262 - val_accuracy: 0.6064 - val_loss: 0.6736 - learning_rate: 5.0000e-04
# Epoch 9/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.6740 - loss: 0.5951 - val_accuracy: 0.5982 - val_loss: 0.6700 - learning_rate: 1.0000e-04
# Epoch 10/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.6886 - loss: 0.5848 - val_accuracy: 0.6070 - val_loss: 0.6707 - learning_rate: 1.0000e-04
# Epoch 11/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.6921 - loss: 0.5754 - val_accuracy: 0.6033 - val_loss: 0.6727 - learning_rate: 1.0000e-04
# Epoch 12/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.7187 - loss: 0.5556 - val_accuracy: 0.5995 - val_loss: 0.6734 - learning_rate: 2.0000e-05
# Epoch 13/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.6993 - loss: 0.5649 - val_accuracy: 0.5989 - val_loss: 0.6738 - learning_rate: 2.0000e-05
# Epoch 14/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.7043 - loss: 0.5622 - val_accuracy: 0.6014 - val_loss: 0.6741 - learning_rate: 2.0000e-05
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 5 Results:
# Accuracy: 0.5982
# Balanced Accuracy: 0.5985
# MCC: 0.1967
# Sensitivity: 0.5936
# Specificity: 0.6034
#
# Average Cross-validation Results:
# ACC: 0.5984 ± 0.0061
# BALANCED_ACC: 0.5980 ± 0.0074
# MCC: 0.1973 ± 0.0151
# SN: 0.6353 ± 0.0455
# SP: 0.5607 ± 0.0457
#
# Final Test Set Results:
# Accuracy: 0.5985
# Balanced Accuracy: 0.5950
# MCC: 0.1087
# Sensitivity: 0.5907
# Specificity: 0.5993
# Confusion Matrix:
# [[1349  902]
#  [  88  127]]

# %% [markdown]
# Simple Attention Model:

# %%
def create_structure_model(window_size=33, n_features=12):
    """Simple attention model"""
    inputs = tf.keras.layers.Input(shape=(window_size, n_features))
    
    # Initial processing
    x = tf.keras.layers.Dense(32, activation='relu')(inputs)
    x = tf.keras.layers.Dropout(0.3)(x)
    
    # Simple attention
    attention = tf.keras.layers.MultiHeadAttention(
        num_heads=2, 
        key_dim=16
    )(x, x)
    x = tf.keras.layers.Add()([x, attention])
    
    # Get central position
    central_pos = window_size // 2
    x = tf.keras.layers.Lambda(lambda x: x[:, central_pos, :])(x)
    
    x = tf.keras.layers.Dense(32, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
if __name__ == "__main__":
    model = train_and_evaluate()
# Out:
# Loading data...
#
# Training set distribution:
# label
# 1    4592
# 0    4258
# Name: count, dtype: int64
#
# Test set distribution:
# label
# 0    2497
# 1     240
# Name: count, dtype: int64
#
# Preparing structure data...
#
# Training data shape: (8850, 33, 12)
# Test data shape: (2737, 33, 12)
#
# Class weights: {0: 1.0392202912165336, 1: 0.9636324041811847}
#
# Fold 1/5
# Epoch 1/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.5307 - loss: 0.7014 - val_accuracy: 0.5198 - val_loss: 0.6900 - learning_rate: 5.0000e-04
# Epoch 2/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5104 - loss: 0.6959 - val_accuracy: 0.5350 - val_loss: 0.6882 - learning_rate: 5.0000e-04
# Epoch 3/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5270 - loss: 0.6886 - val_accuracy: 0.5452 - val_loss: 0.6840 - learning_rate: 5.0000e-04
# Epoch 4/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5360 - loss: 0.6864 - val_accuracy: 0.5661 - val_loss: 0.6818 - learning_rate: 5.0000e-04
# Epoch 5/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5360 - loss: 0.6853 - val_accuracy: 0.5458 - val_loss: 0.6817 - learning_rate: 5.0000e-04
# Epoch 6/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5400 - loss: 0.6844 - val_accuracy: 0.5605 - val_loss: 0.6802 - learning_rate: 5.0000e-04
# Epoch 7/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5346 - loss: 0.6856 - val_accuracy: 0.5593 - val_loss: 0.6802 - learning_rate: 5.0000e-04
# Epoch 8/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5547 - loss: 0.6828 - val_accuracy: 0.5751 - val_loss: 0.6781 - learning_rate: 5.0000e-04
# Epoch 9/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5469 - loss: 0.6808 - val_accuracy: 0.5723 - val_loss: 0.6793 - learning_rate: 5.0000e-04
# Epoch 10/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5578 - loss: 0.6802 - val_accuracy: 0.5650 - val_loss: 0.6776 - learning_rate: 5.0000e-04
# Epoch 11/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5553 - loss: 0.6812 - val_accuracy: 0.5723 - val_loss: 0.6766 - learning_rate: 5.0000e-04
# Epoch 12/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5624 - loss: 0.6815 - val_accuracy: 0.5780 - val_loss: 0.6761 - learning_rate: 5.0000e-04
# Epoch 13/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5589 - loss: 0.6799 - val_accuracy: 0.5734 - val_loss: 0.6765 - learning_rate: 5.0000e-04
# Epoch 14/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5528 - loss: 0.6800 - val_accuracy: 0.5780 - val_loss: 0.6750 - learning_rate: 5.0000e-04
# Epoch 15/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5617 - loss: 0.6772 - val_accuracy: 0.5763 - val_loss: 0.6749 - learning_rate: 5.0000e-04
# Epoch 16/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5714 - loss: 0.6756 - val_accuracy: 0.5785 - val_loss: 0.6749 - learning_rate: 5.0000e-04
# Epoch 17/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5653 - loss: 0.6764 - val_accuracy: 0.5836 - val_loss: 0.6740 - learning_rate: 5.0000e-04
# Epoch 18/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5660 - loss: 0.6760 - val_accuracy: 0.5898 - val_loss: 0.6748 - learning_rate: 5.0000e-04
# Epoch 19/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5644 - loss: 0.6759 - val_accuracy: 0.5842 - val_loss: 0.6734 - learning_rate: 5.0000e-04
# Epoch 20/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5712 - loss: 0.6754 - val_accuracy: 0.5808 - val_loss: 0.6738 - learning_rate: 5.0000e-04
# Epoch 21/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5678 - loss: 0.6754 - val_accuracy: 0.5910 - val_loss: 0.6733 - learning_rate: 5.0000e-04
# Epoch 22/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5724 - loss: 0.6760 - val_accuracy: 0.5887 - val_loss: 0.6726 - learning_rate: 5.0000e-04
# Epoch 23/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5660 - loss: 0.6758 - val_accuracy: 0.5881 - val_loss: 0.6723 - learning_rate: 5.0000e-04
# Epoch 24/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5629 - loss: 0.6732 - val_accuracy: 0.5836 - val_loss: 0.6739 - learning_rate: 5.0000e-04
# Epoch 25/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.5708 - loss: 0.6736 - val_accuracy: 0.5870 - val_loss: 0.6718 - learning_rate: 5.0000e-04
# Epoch 26/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5673 - loss: 0.6718 - val_accuracy: 0.5847 - val_loss: 0.6725 - learning_rate: 5.0000e-04
# Epoch 27/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5748 - loss: 0.6725 - val_accuracy: 0.5842 - val_loss: 0.6722 - learning_rate: 5.0000e-04
# Epoch 28/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5757 - loss: 0.6722 - val_accuracy: 0.5825 - val_loss: 0.6721 - learning_rate: 5.0000e-04
# Epoch 29/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5744 - loss: 0.6713 - val_accuracy: 0.5876 - val_loss: 0.6735 - learning_rate: 1.0000e-04
# Epoch 30/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.5804 - loss: 0.6703 - val_accuracy: 0.5842 - val_loss: 0.6737 - learning_rate: 1.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#
# Fold 1 Results:
# Accuracy: 0.5870
# Balanced Accuracy: 0.5700
# MCC: 0.1517
# Sensitivity: 0.7604
# Specificity: 0.3797
#
# Fold 2/5
# Epoch 1/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.5046 - loss: 0.6955 - val_accuracy: 0.5107 - val_loss: 0.6900 - learning_rate: 5.0000e-04
# Epoch 2/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.5032 - loss: 0.6927 - val_accuracy: 0.5446 - val_loss: 0.6850 - learning_rate: 5.0000e-04
# Epoch 3/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.5243 - loss: 0.6881 - val_accuracy: 0.5706 - val_loss: 0.6828 - learning_rate: 5.0000e-04
# Epoch 4/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.5257 - loss: 0.6870 - val_accuracy: 0.5740 - val_loss: 0.6814 - learning_rate: 5.0000e-04
# Epoch 5/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5459 - loss: 0.6830 - val_accuracy: 0.5808 - val_loss: 0.6794 - learning_rate: 5.0000e-04
# Epoch 6/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5561 - loss: 0.6823 - val_accuracy: 0.5842 - val_loss: 0.6782 - learning_rate: 5.0000e-04
# Epoch 7/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5532 - loss: 0.6808 - val_accuracy: 0.5650 - val_loss: 0.6778 - learning_rate: 5.0000e-04
# Epoch 8/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5431 - loss: 0.6844 - val_accuracy: 0.5723 - val_loss: 0.6771 - learning_rate: 5.0000e-04
# Epoch 9/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5568 - loss: 0.6810 - val_accuracy: 0.5571 - val_loss: 0.6781 - learning_rate: 5.0000e-04
# Epoch 10/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5596 - loss: 0.6813 - val_accuracy: 0.5655 - val_loss: 0.6776 - learning_rate: 5.0000e-04
# Epoch 11/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5580 - loss: 0.6813 - val_accuracy: 0.5621 - val_loss: 0.6761 - learning_rate: 5.0000e-04
# Epoch 12/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5525 - loss: 0.6795 - val_accuracy: 0.5785 - val_loss: 0.6754 - learning_rate: 5.0000e-04
# Epoch 13/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5683 - loss: 0.6790 - val_accuracy: 0.5655 - val_loss: 0.6766 - learning_rate: 5.0000e-04
# Epoch 14/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5628 - loss: 0.6805 - val_accuracy: 0.5842 - val_loss: 0.6749 - learning_rate: 5.0000e-04
# Epoch 15/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5610 - loss: 0.6766 - val_accuracy: 0.5757 - val_loss: 0.6750 - learning_rate: 5.0000e-04
# Epoch 16/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5656 - loss: 0.6763 - val_accuracy: 0.5667 - val_loss: 0.6755 - learning_rate: 5.0000e-04
# Epoch 17/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5652 - loss: 0.6782 - val_accuracy: 0.5695 - val_loss: 0.6762 - learning_rate: 5.0000e-04
# Epoch 18/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5743 - loss: 0.6755 - val_accuracy: 0.5723 - val_loss: 0.6749 - learning_rate: 1.0000e-04
# Epoch 19/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5767 - loss: 0.6744 - val_accuracy: 0.5712 - val_loss: 0.6752 - learning_rate: 1.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Fold 2 Results:
# Accuracy: 0.5842
# Balanced Accuracy: 0.5709
# MCC: 0.1573
# Sensitivity: 0.7840
# Specificity: 0.3578
#
# Fold 3/5
# Epoch 1/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.5016 - loss: 0.7148 - val_accuracy: 0.5119 - val_loss: 0.6914 - learning_rate: 5.0000e-04
# Epoch 2/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5089 - loss: 0.6966 - val_accuracy: 0.5243 - val_loss: 0.6907 - learning_rate: 5.0000e-04
# Epoch 3/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5279 - loss: 0.6909 - val_accuracy: 0.5124 - val_loss: 0.6894 - learning_rate: 5.0000e-04
# Epoch 4/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5112 - loss: 0.6931 - val_accuracy: 0.5322 - val_loss: 0.6872 - learning_rate: 5.0000e-04
# Epoch 5/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5416 - loss: 0.6883 - val_accuracy: 0.5373 - val_loss: 0.6849 - learning_rate: 5.0000e-04
# Epoch 6/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5347 - loss: 0.6871 - val_accuracy: 0.5333 - val_loss: 0.6832 - learning_rate: 5.0000e-04
# Epoch 7/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5375 - loss: 0.6835 - val_accuracy: 0.5503 - val_loss: 0.6814 - learning_rate: 5.0000e-04
# Epoch 8/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5437 - loss: 0.6828 - val_accuracy: 0.5503 - val_loss: 0.6807 - learning_rate: 5.0000e-04
# Epoch 9/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5430 - loss: 0.6843 - val_accuracy: 0.5627 - val_loss: 0.6803 - learning_rate: 5.0000e-04
# Epoch 10/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5519 - loss: 0.6822 - val_accuracy: 0.5576 - val_loss: 0.6793 - learning_rate: 5.0000e-04
# Epoch 11/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5419 - loss: 0.6839 - val_accuracy: 0.5746 - val_loss: 0.6783 - learning_rate: 5.0000e-04
# Epoch 12/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5465 - loss: 0.6825 - val_accuracy: 0.5785 - val_loss: 0.6781 - learning_rate: 5.0000e-04
# Epoch 13/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5559 - loss: 0.6802 - val_accuracy: 0.5757 - val_loss: 0.6771 - learning_rate: 5.0000e-04
# Epoch 14/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5544 - loss: 0.6794 - val_accuracy: 0.5746 - val_loss: 0.6767 - learning_rate: 5.0000e-04
# Epoch 15/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.5540 - loss: 0.6797 - val_accuracy: 0.5757 - val_loss: 0.6751 - learning_rate: 5.0000e-04
# Epoch 16/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5565 - loss: 0.6797 - val_accuracy: 0.5661 - val_loss: 0.6759 - learning_rate: 5.0000e-04
# Epoch 17/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5499 - loss: 0.6785 - val_accuracy: 0.5808 - val_loss: 0.6742 - learning_rate: 5.0000e-04
# Epoch 18/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5590 - loss: 0.6783 - val_accuracy: 0.5802 - val_loss: 0.6737 - learning_rate: 5.0000e-04
# Epoch 19/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5650 - loss: 0.6769 - val_accuracy: 0.5819 - val_loss: 0.6728 - learning_rate: 5.0000e-04
# Epoch 20/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5648 - loss: 0.6767 - val_accuracy: 0.5616 - val_loss: 0.6726 - learning_rate: 5.0000e-04
# Epoch 21/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5616 - loss: 0.6772 - val_accuracy: 0.5847 - val_loss: 0.6713 - learning_rate: 5.0000e-04
# Epoch 22/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5571 - loss: 0.6785 - val_accuracy: 0.5763 - val_loss: 0.6720 - learning_rate: 5.0000e-04
# Epoch 23/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5745 - loss: 0.6729 - val_accuracy: 0.5797 - val_loss: 0.6713 - learning_rate: 5.0000e-04
# Epoch 24/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5627 - loss: 0.6763 - val_accuracy: 0.5881 - val_loss: 0.6716 - learning_rate: 5.0000e-04
# Epoch 25/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5721 - loss: 0.6735 - val_accuracy: 0.5814 - val_loss: 0.6692 - learning_rate: 1.0000e-04
# Epoch 26/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5686 - loss: 0.6745 - val_accuracy: 0.5808 - val_loss: 0.6685 - learning_rate: 1.0000e-04
# Epoch 27/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5761 - loss: 0.6716 - val_accuracy: 0.5780 - val_loss: 0.6690 - learning_rate: 1.0000e-04
# Epoch 28/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.5872 - loss: 0.6690 - val_accuracy: 0.5825 - val_loss: 0.6680 - learning_rate: 1.0000e-04
# Epoch 29/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5817 - loss: 0.6709 - val_accuracy: 0.5768 - val_loss: 0.6684 - learning_rate: 1.0000e-04
# Epoch 30/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.5816 - loss: 0.6702 - val_accuracy: 0.5814 - val_loss: 0.6673 - learning_rate: 1.0000e-04
# Epoch 31/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5813 - loss: 0.6716 - val_accuracy: 0.5802 - val_loss: 0.6680 - learning_rate: 1.0000e-04
# Epoch 32/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.5729 - loss: 0.6714 - val_accuracy: 0.5797 - val_loss: 0.6679 - learning_rate: 1.0000e-04
# Epoch 33/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5766 - loss: 0.6720 - val_accuracy: 0.5819 - val_loss: 0.6677 - learning_rate: 1.0000e-04
# Epoch 34/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5765 - loss: 0.6718 - val_accuracy: 0.5836 - val_loss: 0.6675 - learning_rate: 2.0000e-05
# Epoch 35/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.5715 - loss: 0.6713 - val_accuracy: 0.5825 - val_loss: 0.6672 - learning_rate: 2.0000e-05
# Epoch 36/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5670 - loss: 0.6744 - val_accuracy: 0.5836 - val_loss: 0.6672 - learning_rate: 2.0000e-05
# Epoch 37/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5721 - loss: 0.6733 - val_accuracy: 0.5831 - val_loss: 0.6672 - learning_rate: 4.0000e-06
# Epoch 38/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5728 - loss: 0.6714 - val_accuracy: 0.5836 - val_loss: 0.6672 - learning_rate: 4.0000e-06
# Epoch 39/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5859 - loss: 0.6716 - val_accuracy: 0.5836 - val_loss: 0.6672 - learning_rate: 4.0000e-06
# Epoch 40/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5801 - loss: 0.6716 - val_accuracy: 0.5831 - val_loss: 0.6671 - learning_rate: 4.0000e-06
# Epoch 41/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5815 - loss: 0.6735 - val_accuracy: 0.5831 - val_loss: 0.6671 - learning_rate: 1.0000e-06
# Epoch 42/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.5803 - loss: 0.6738 - val_accuracy: 0.5831 - val_loss: 0.6671 - learning_rate: 1.0000e-06
# Epoch 43/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.5750 - loss: 0.6707 - val_accuracy: 0.5831 - val_loss: 0.6671 - learning_rate: 1.0000e-06
# Epoch 44/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5806 - loss: 0.6710 - val_accuracy: 0.5825 - val_loss: 0.6671 - learning_rate: 1.0000e-06
# Epoch 45/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5693 - loss: 0.6729 - val_accuracy: 0.5831 - val_loss: 0.6671 - learning_rate: 1.0000e-06
# Epoch 46/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5754 - loss: 0.6731 - val_accuracy: 0.5825 - val_loss: 0.6671 - learning_rate: 1.0000e-06
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 3 Results:
# Accuracy: 0.5831
# Balanced Accuracy: 0.5820
# MCC: 0.1690
# Sensitivity: 0.7032
# Specificity: 0.4607
#
# Fold 4/5
# Epoch 1/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.4957 - loss: 0.7029 - val_accuracy: 0.5209 - val_loss: 0.6911 - learning_rate: 5.0000e-04
# Epoch 2/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5045 - loss: 0.6935 - val_accuracy: 0.5249 - val_loss: 0.6909 - learning_rate: 5.0000e-04
# Epoch 3/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.5267 - loss: 0.6909 - val_accuracy: 0.5328 - val_loss: 0.6862 - learning_rate: 5.0000e-04
# Epoch 4/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5390 - loss: 0.6833 - val_accuracy: 0.5395 - val_loss: 0.6831 - learning_rate: 5.0000e-04
# Epoch 5/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5349 - loss: 0.6842 - val_accuracy: 0.5356 - val_loss: 0.6832 - learning_rate: 5.0000e-04
# Epoch 6/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.5438 - loss: 0.6826 - val_accuracy: 0.5350 - val_loss: 0.6827 - learning_rate: 5.0000e-04
# Epoch 7/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5549 - loss: 0.6807 - val_accuracy: 0.5610 - val_loss: 0.6810 - learning_rate: 5.0000e-04
# Epoch 8/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5409 - loss: 0.6808 - val_accuracy: 0.5531 - val_loss: 0.6808 - learning_rate: 5.0000e-04
# Epoch 9/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.5561 - loss: 0.6822 - val_accuracy: 0.5503 - val_loss: 0.6808 - learning_rate: 5.0000e-04
# Epoch 10/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.5465 - loss: 0.6782 - val_accuracy: 0.5554 - val_loss: 0.6799 - learning_rate: 5.0000e-04
# Epoch 11/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5713 - loss: 0.6786 - val_accuracy: 0.5548 - val_loss: 0.6792 - learning_rate: 5.0000e-04
# Epoch 12/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5692 - loss: 0.6781 - val_accuracy: 0.5559 - val_loss: 0.6782 - learning_rate: 5.0000e-04
# Epoch 13/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5632 - loss: 0.6760 - val_accuracy: 0.5605 - val_loss: 0.6781 - learning_rate: 5.0000e-04
# Epoch 14/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5705 - loss: 0.6757 - val_accuracy: 0.5627 - val_loss: 0.6776 - learning_rate: 5.0000e-04
# Epoch 15/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5798 - loss: 0.6747 - val_accuracy: 0.5599 - val_loss: 0.6783 - learning_rate: 5.0000e-04
# Epoch 16/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5610 - loss: 0.6784 - val_accuracy: 0.5706 - val_loss: 0.6767 - learning_rate: 5.0000e-04
# Epoch 17/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5749 - loss: 0.6759 - val_accuracy: 0.5678 - val_loss: 0.6763 - learning_rate: 5.0000e-04
# Epoch 18/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5803 - loss: 0.6730 - val_accuracy: 0.5638 - val_loss: 0.6764 - learning_rate: 5.0000e-04
# Epoch 19/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5718 - loss: 0.6741 - val_accuracy: 0.5661 - val_loss: 0.6757 - learning_rate: 5.0000e-04
# Epoch 20/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5884 - loss: 0.6716 - val_accuracy: 0.5695 - val_loss: 0.6740 - learning_rate: 5.0000e-04
# Epoch 21/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5750 - loss: 0.6724 - val_accuracy: 0.5672 - val_loss: 0.6737 - learning_rate: 5.0000e-04
# Epoch 22/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5821 - loss: 0.6756 - val_accuracy: 0.5678 - val_loss: 0.6732 - learning_rate: 5.0000e-04
# Epoch 23/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5709 - loss: 0.6718 - val_accuracy: 0.5655 - val_loss: 0.6737 - learning_rate: 5.0000e-04
# Epoch 24/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5818 - loss: 0.6727 - val_accuracy: 0.5734 - val_loss: 0.6728 - learning_rate: 5.0000e-04
# Epoch 25/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5843 - loss: 0.6707 - val_accuracy: 0.5723 - val_loss: 0.6729 - learning_rate: 5.0000e-04
# Epoch 26/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5790 - loss: 0.6689 - val_accuracy: 0.5734 - val_loss: 0.6725 - learning_rate: 5.0000e-04
# Epoch 27/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5857 - loss: 0.6708 - val_accuracy: 0.5712 - val_loss: 0.6726 - learning_rate: 5.0000e-04
# Epoch 28/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5808 - loss: 0.6686 - val_accuracy: 0.5763 - val_loss: 0.6725 - learning_rate: 5.0000e-04
# Epoch 29/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5831 - loss: 0.6679 - val_accuracy: 0.5774 - val_loss: 0.6726 - learning_rate: 5.0000e-04
# Epoch 30/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5916 - loss: 0.6710 - val_accuracy: 0.5729 - val_loss: 0.6707 - learning_rate: 1.0000e-04
# Epoch 31/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5857 - loss: 0.6666 - val_accuracy: 0.5746 - val_loss: 0.6706 - learning_rate: 1.0000e-04
# Epoch 32/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.5845 - loss: 0.6692 - val_accuracy: 0.5650 - val_loss: 0.6708 - learning_rate: 1.0000e-04
# Epoch 33/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5840 - loss: 0.6660 - val_accuracy: 0.5746 - val_loss: 0.6706 - learning_rate: 1.0000e-04
# Epoch 34/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5869 - loss: 0.6676 - val_accuracy: 0.5706 - val_loss: 0.6703 - learning_rate: 1.0000e-04
# Epoch 35/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5858 - loss: 0.6669 - val_accuracy: 0.5689 - val_loss: 0.6705 - learning_rate: 1.0000e-04
# Epoch 36/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5918 - loss: 0.6667 - val_accuracy: 0.5672 - val_loss: 0.6705 - learning_rate: 1.0000e-04
# Epoch 37/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5834 - loss: 0.6669 - val_accuracy: 0.5672 - val_loss: 0.6705 - learning_rate: 1.0000e-04
# Epoch 38/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5902 - loss: 0.6672 - val_accuracy: 0.5678 - val_loss: 0.6705 - learning_rate: 2.0000e-05
# Epoch 39/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5970 - loss: 0.6673 - val_accuracy: 0.5701 - val_loss: 0.6704 - learning_rate: 2.0000e-05
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Fold 4 Results:
# Accuracy: 0.5706
# Balanced Accuracy: 0.5721
# MCC: 0.1590
# Sensitivity: 0.7838
# Specificity: 0.3603
#
# Fold 5/5
# Epoch 1/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.5092 - loss: 0.7087 - val_accuracy: 0.5446 - val_loss: 0.6887 - learning_rate: 5.0000e-04
# Epoch 2/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5324 - loss: 0.6890 - val_accuracy: 0.5531 - val_loss: 0.6870 - learning_rate: 5.0000e-04
# Epoch 3/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5353 - loss: 0.6867 - val_accuracy: 0.5412 - val_loss: 0.6858 - learning_rate: 5.0000e-04
# Epoch 4/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5446 - loss: 0.6842 - val_accuracy: 0.5616 - val_loss: 0.6841 - learning_rate: 5.0000e-04
# Epoch 5/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5411 - loss: 0.6832 - val_accuracy: 0.5542 - val_loss: 0.6832 - learning_rate: 5.0000e-04
# Epoch 6/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5459 - loss: 0.6814 - val_accuracy: 0.5684 - val_loss: 0.6823 - learning_rate: 5.0000e-04
# Epoch 7/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5503 - loss: 0.6791 - val_accuracy: 0.5729 - val_loss: 0.6814 - learning_rate: 5.0000e-04
# Epoch 8/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5603 - loss: 0.6775 - val_accuracy: 0.5599 - val_loss: 0.6810 - learning_rate: 5.0000e-04
# Epoch 9/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5619 - loss: 0.6783 - val_accuracy: 0.5616 - val_loss: 0.6808 - learning_rate: 5.0000e-04
# Epoch 10/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5691 - loss: 0.6760 - val_accuracy: 0.5661 - val_loss: 0.6805 - learning_rate: 5.0000e-04
# Epoch 11/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5628 - loss: 0.6752 - val_accuracy: 0.5706 - val_loss: 0.6795 - learning_rate: 5.0000e-04
# Epoch 12/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5788 - loss: 0.6757 - val_accuracy: 0.5644 - val_loss: 0.6810 - learning_rate: 5.0000e-04
# Epoch 13/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5700 - loss: 0.6766 - val_accuracy: 0.5650 - val_loss: 0.6788 - learning_rate: 5.0000e-04
# Epoch 14/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5703 - loss: 0.6765 - val_accuracy: 0.5718 - val_loss: 0.6783 - learning_rate: 5.0000e-04
# Epoch 15/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5794 - loss: 0.6715 - val_accuracy: 0.5695 - val_loss: 0.6786 - learning_rate: 5.0000e-04
# Epoch 16/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5745 - loss: 0.6719 - val_accuracy: 0.5701 - val_loss: 0.6793 - learning_rate: 5.0000e-04
# Epoch 17/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5813 - loss: 0.6734 - val_accuracy: 0.5774 - val_loss: 0.6776 - learning_rate: 5.0000e-04
# Epoch 18/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5761 - loss: 0.6727 - val_accuracy: 0.5718 - val_loss: 0.6784 - learning_rate: 5.0000e-04
# Epoch 19/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5892 - loss: 0.6695 - val_accuracy: 0.5740 - val_loss: 0.6779 - learning_rate: 5.0000e-04
# Epoch 20/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5814 - loss: 0.6715 - val_accuracy: 0.5791 - val_loss: 0.6769 - learning_rate: 5.0000e-04
# Epoch 21/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5832 - loss: 0.6680 - val_accuracy: 0.5729 - val_loss: 0.6792 - learning_rate: 5.0000e-04
# Epoch 22/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5761 - loss: 0.6712 - val_accuracy: 0.5797 - val_loss: 0.6769 - learning_rate: 5.0000e-04
# Epoch 23/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5819 - loss: 0.6688 - val_accuracy: 0.5734 - val_loss: 0.6773 - learning_rate: 5.0000e-04
# Epoch 24/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5815 - loss: 0.6673 - val_accuracy: 0.5757 - val_loss: 0.6764 - learning_rate: 1.0000e-04
# Epoch 25/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5886 - loss: 0.6674 - val_accuracy: 0.5689 - val_loss: 0.6756 - learning_rate: 1.0000e-04
# Epoch 26/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5805 - loss: 0.6695 - val_accuracy: 0.5723 - val_loss: 0.6763 - learning_rate: 1.0000e-04
# Epoch 27/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5802 - loss: 0.6670 - val_accuracy: 0.5740 - val_loss: 0.6763 - learning_rate: 1.0000e-04
# Epoch 28/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5751 - loss: 0.6694 - val_accuracy: 0.5757 - val_loss: 0.6762 - learning_rate: 1.0000e-04
# Epoch 29/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5852 - loss: 0.6666 - val_accuracy: 0.5734 - val_loss: 0.6760 - learning_rate: 2.0000e-05
# Epoch 30/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5847 - loss: 0.6667 - val_accuracy: 0.5729 - val_loss: 0.6760 - learning_rate: 2.0000e-05
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Fold 5 Results:
# Accuracy: 0.5689
# Balanced Accuracy: 0.5628
# MCC: 0.1342
# Sensitivity: 0.7380
# Specificity: 0.3876
#
# Average Cross-validation Results:
# ACC: 0.5788 ± 0.0075
# BALANCED_ACC: 0.5716 ± 0.0061
# MCC: 0.1542 ± 0.0115
# SN: 0.7539 ± 0.0305
# SP: 0.3892 ± 0.0375
#
# Final Test Set Results:
# Accuracy: 0.4885
# Balanced Accuracy: 0.5652
# MCC: 0.0740
# Sensitivity: 0.6583
# Specificity: 0.4722
# Confusion Matrix:
# [[1179 1318]
#  [  82  158]]

# %%
def create_structure_model(window_size=33, n_features=12):
    """More complex model with strong regularization"""
    inputs = tf.keras.layers.Input(shape=(window_size, n_features))
    
    # Initial feature processing
    x = tf.keras.layers.BatchNormalization()(inputs)
    
    # CNN branch for local features
    conv1 = tf.keras.layers.Conv1D(
        filters=64,
        kernel_size=3,
        padding='same',
        kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(x)
    conv1 = tf.keras.layers.BatchNormalization()(conv1)
    conv1 = tf.keras.layers.Activation('relu')(conv1)
    
    conv2 = tf.keras.layers.Conv1D(
        filters=64,
        kernel_size=5,
        padding='same',
        kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(x)
    conv2 = tf.keras.layers.BatchNormalization()(conv2)
    conv2 = tf.keras.layers.Activation('relu')(conv2)
    
    # Combine CNN features
    x = tf.keras.layers.Concatenate()([conv1, conv2])
    x = tf.keras.layers.Dropout(0.3)(x)
    
    # BiLSTM for sequential features
    x = tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(
            64,
            return_sequences=True,
            kernel_regularizer=tf.keras.regularizers.l2(0.01),
            recurrent_regularizer=tf.keras.regularizers.l2(0.01)
        )
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    
    # Attention mechanism
    attention = tf.keras.layers.MultiHeadAttention(
        num_heads=4,
        key_dim=32,
        kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(x, x)
    x = tf.keras.layers.Add()([x, attention])
    x = tf.keras.layers.LayerNormalization()(x)
    
    # Extract central window (K residue ± 2 positions)
    central_pos = window_size // 2
    x = tf.keras.layers.Lambda(
        lambda x: x[:, central_pos-2:central_pos+3, :]
    )(x)
    
    # Dense feature processing
    x = tf.keras.layers.Flatten()(x)
    
    x = tf.keras.layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    
    x = tf.keras.layers.Dense(
        64,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    
    # Output
    outputs = tf.keras.layers.Dense(
        1,
        activation='sigmoid',
        kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(x)
    
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
if __name__ == "__main__":
    model = train_and_evaluate()
# Out:
# Loading data...
#
# Training set distribution:
# label
# 1    4592
# 0    4258
# Name: count, dtype: int64
#
# Test set distribution:
# label
# 0    2497
# 1     240
# Name: count, dtype: int64
#
# Preparing structure data...
#
# Training data shape: (8850, 33, 12)
# Test data shape: (2737, 33, 12)
#
# Class weights: {0: 1.0392202912165336, 1: 0.9636324041811847}
#
# Fold 1/5
# Epoch 1/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 31s 204ms/step - accuracy: 0.5224 - loss: 8.7780 - val_accuracy: 0.5881 - val_loss: 6.2097 - learning_rate: 5.0000e-04
# Epoch 2/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - accuracy: 0.5347 - loss: 5.6680 - val_accuracy: 0.5819 - val_loss: 4.0850 - learning_rate: 5.0000e-04
# Epoch 3/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - accuracy: 0.5499 - loss: 3.8202 - val_accuracy: 0.5610 - val_loss: 2.9479 - learning_rate: 5.0000e-04
# Epoch 4/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 22s 195ms/step - accuracy: 0.5561 - loss: 2.7896 - val_accuracy: 0.5638 - val_loss: 2.2434 - learning_rate: 5.0000e-04
# Epoch 5/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 193ms/step - accuracy: 0.5553 - loss: 2.1459 - val_accuracy: 0.5853 - val_loss: 1.7693 - learning_rate: 5.0000e-04
# Epoch 6/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5587 - loss: 1.7148 - val_accuracy: 0.5876 - val_loss: 1.4618 - learning_rate: 5.0000e-04
# Epoch 7/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.5785 - loss: 1.4199 - val_accuracy: 0.5655 - val_loss: 1.2694 - learning_rate: 5.0000e-04
# Epoch 8/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.5916 - loss: 1.2390 - val_accuracy: 0.5898 - val_loss: 1.1237 - learning_rate: 5.0000e-04
# Epoch 9/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.5795 - loss: 1.1056 - val_accuracy: 0.5972 - val_loss: 1.0224 - learning_rate: 5.0000e-04
# Epoch 10/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.5965 - loss: 1.0050 - val_accuracy: 0.5972 - val_loss: 0.9439 - learning_rate: 5.0000e-04
# Epoch 11/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.6033 - loss: 0.9372 - val_accuracy: 0.5893 - val_loss: 0.9009 - learning_rate: 5.0000e-04
# Epoch 12/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5766 - loss: 0.8914 - val_accuracy: 0.5559 - val_loss: 0.8807 - learning_rate: 5.0000e-04
# Epoch 13/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.5980 - loss: 0.8452 - val_accuracy: 0.5701 - val_loss: 0.8307 - learning_rate: 5.0000e-04
# Epoch 14/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5941 - loss: 0.8154 - val_accuracy: 0.5983 - val_loss: 0.7952 - learning_rate: 5.0000e-04
# Epoch 15/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.6113 - loss: 0.7869 - val_accuracy: 0.5989 - val_loss: 0.7746 - learning_rate: 5.0000e-04
# Epoch 16/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.6024 - loss: 0.7699 - val_accuracy: 0.5949 - val_loss: 0.7603 - learning_rate: 5.0000e-04
# Epoch 17/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.6108 - loss: 0.7515 - val_accuracy: 0.5972 - val_loss: 0.7605 - learning_rate: 5.0000e-04
# Epoch 18/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6076 - loss: 0.7446 - val_accuracy: 0.6232 - val_loss: 0.7384 - learning_rate: 5.0000e-04
# Epoch 19/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.6101 - loss: 0.7371 - val_accuracy: 0.5887 - val_loss: 0.7346 - learning_rate: 5.0000e-04
# Epoch 20/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 193ms/step - accuracy: 0.6098 - loss: 0.7245 - val_accuracy: 0.5904 - val_loss: 0.7303 - learning_rate: 5.0000e-04
# Epoch 21/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6104 - loss: 0.7175 - val_accuracy: 0.6136 - val_loss: 0.7197 - learning_rate: 5.0000e-04
# Epoch 22/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 185ms/step - accuracy: 0.6095 - loss: 0.7122 - val_accuracy: 0.5927 - val_loss: 0.7207 - learning_rate: 5.0000e-04
# Epoch 23/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6101 - loss: 0.7130 - val_accuracy: 0.6209 - val_loss: 0.7088 - learning_rate: 5.0000e-04
# Epoch 24/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6178 - loss: 0.7052 - val_accuracy: 0.5994 - val_loss: 0.7230 - learning_rate: 5.0000e-04
# Epoch 25/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6186 - loss: 0.7032 - val_accuracy: 0.6294 - val_loss: 0.7024 - learning_rate: 5.0000e-04
# Epoch 26/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6334 - loss: 0.7023 - val_accuracy: 0.5910 - val_loss: 0.7221 - learning_rate: 5.0000e-04
# Epoch 27/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6224 - loss: 0.6969 - val_accuracy: 0.6023 - val_loss: 0.7174 - learning_rate: 5.0000e-04
# Epoch 28/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6224 - loss: 0.6958 - val_accuracy: 0.6085 - val_loss: 0.7124 - learning_rate: 5.0000e-04
# Epoch 29/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 185ms/step - accuracy: 0.6354 - loss: 0.6850 - val_accuracy: 0.6350 - val_loss: 0.6987 - learning_rate: 1.0000e-04
# Epoch 30/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6415 - loss: 0.6695 - val_accuracy: 0.6373 - val_loss: 0.7002 - learning_rate: 1.0000e-04
# Epoch 31/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6520 - loss: 0.6629 - val_accuracy: 0.6288 - val_loss: 0.7077 - learning_rate: 1.0000e-04
# Epoch 32/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6532 - loss: 0.6586 - val_accuracy: 0.6282 - val_loss: 0.7052 - learning_rate: 1.0000e-04
# Epoch 33/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6596 - loss: 0.6494 - val_accuracy: 0.6350 - val_loss: 0.7103 - learning_rate: 2.0000e-05
# Epoch 34/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6562 - loss: 0.6506 - val_accuracy: 0.6288 - val_loss: 0.7162 - learning_rate: 2.0000e-05
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step
#
# Fold 1 Results:
# Accuracy: 0.6350
# Balanced Accuracy: 0.6288
# MCC: 0.2601
# Sensitivity: 0.6981
# Specificity: 0.5596
#
# Fold 2/5
# Epoch 1/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 31s 205ms/step - accuracy: 0.5086 - loss: 8.9397 - val_accuracy: 0.5418 - val_loss: 6.5370 - learning_rate: 5.0000e-04
# Epoch 2/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.5331 - loss: 6.0614 - val_accuracy: 0.5226 - val_loss: 4.5007 - learning_rate: 5.0000e-04
# Epoch 3/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.5389 - loss: 4.1740 - val_accuracy: 0.5774 - val_loss: 3.2277 - learning_rate: 5.0000e-04
# Epoch 4/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.5582 - loss: 3.0570 - val_accuracy: 0.5768 - val_loss: 2.4708 - learning_rate: 5.0000e-04
# Epoch 5/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 185ms/step - accuracy: 0.5534 - loss: 2.3838 - val_accuracy: 0.5938 - val_loss: 1.9811 - learning_rate: 5.0000e-04
# Epoch 6/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.5710 - loss: 1.9180 - val_accuracy: 0.5927 - val_loss: 1.6510 - learning_rate: 5.0000e-04
# Epoch 7/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.5713 - loss: 1.6059 - val_accuracy: 0.5938 - val_loss: 1.4077 - learning_rate: 5.0000e-04
# Epoch 8/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.5798 - loss: 1.3835 - val_accuracy: 0.5910 - val_loss: 1.2428 - learning_rate: 5.0000e-04
# Epoch 9/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 22s 196ms/step - accuracy: 0.5792 - loss: 1.2229 - val_accuracy: 0.5904 - val_loss: 1.1185 - learning_rate: 5.0000e-04
# Epoch 10/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5907 - loss: 1.0968 - val_accuracy: 0.5938 - val_loss: 1.0305 - learning_rate: 5.0000e-04
# Epoch 11/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.5961 - loss: 1.0091 - val_accuracy: 0.5701 - val_loss: 0.9746 - learning_rate: 5.0000e-04
# Epoch 12/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - accuracy: 0.6049 - loss: 0.9341 - val_accuracy: 0.5706 - val_loss: 0.9284 - learning_rate: 5.0000e-04
# Epoch 13/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6020 - loss: 0.8896 - val_accuracy: 0.6000 - val_loss: 0.8613 - learning_rate: 5.0000e-04
# Epoch 14/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6089 - loss: 0.8418 - val_accuracy: 0.5960 - val_loss: 0.8337 - learning_rate: 5.0000e-04
# Epoch 15/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 192ms/step - accuracy: 0.6136 - loss: 0.8121 - val_accuracy: 0.5966 - val_loss: 0.8060 - learning_rate: 5.0000e-04
# Epoch 16/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.6186 - loss: 0.7869 - val_accuracy: 0.5797 - val_loss: 0.8093 - learning_rate: 5.0000e-04
# Epoch 17/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6171 - loss: 0.7688 - val_accuracy: 0.5955 - val_loss: 0.7671 - learning_rate: 5.0000e-04
# Epoch 18/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - accuracy: 0.6282 - loss: 0.7494 - val_accuracy: 0.5819 - val_loss: 0.7824 - learning_rate: 5.0000e-04
# Epoch 19/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6309 - loss: 0.7375 - val_accuracy: 0.6068 - val_loss: 0.7512 - learning_rate: 5.0000e-04
# Epoch 20/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.6256 - loss: 0.7261 - val_accuracy: 0.6040 - val_loss: 0.7412 - learning_rate: 5.0000e-04
# Epoch 21/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - accuracy: 0.6294 - loss: 0.7176 - val_accuracy: 0.5938 - val_loss: 0.7408 - learning_rate: 5.0000e-04
# Epoch 22/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.6323 - loss: 0.7099 - val_accuracy: 0.5949 - val_loss: 0.7356 - learning_rate: 5.0000e-04
# Epoch 23/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.6382 - loss: 0.7075 - val_accuracy: 0.5966 - val_loss: 0.7255 - learning_rate: 5.0000e-04
# Epoch 24/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.6311 - loss: 0.7015 - val_accuracy: 0.5864 - val_loss: 0.7309 - learning_rate: 5.0000e-04
# Epoch 25/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6370 - loss: 0.6952 - val_accuracy: 0.6017 - val_loss: 0.7334 - learning_rate: 5.0000e-04
# Epoch 26/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.6334 - loss: 0.6940 - val_accuracy: 0.5718 - val_loss: 0.7385 - learning_rate: 5.0000e-04
# Epoch 27/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6438 - loss: 0.6893 - val_accuracy: 0.5977 - val_loss: 0.7175 - learning_rate: 1.0000e-04
# Epoch 28/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6548 - loss: 0.6721 - val_accuracy: 0.6011 - val_loss: 0.7111 - learning_rate: 1.0000e-04
# Epoch 29/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.6545 - loss: 0.6674 - val_accuracy: 0.6011 - val_loss: 0.7133 - learning_rate: 1.0000e-04
# Epoch 30/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.6576 - loss: 0.6613 - val_accuracy: 0.6096 - val_loss: 0.7152 - learning_rate: 1.0000e-04
# Epoch 31/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6648 - loss: 0.6548 - val_accuracy: 0.5938 - val_loss: 0.7230 - learning_rate: 1.0000e-04
# Epoch 32/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.6719 - loss: 0.6494 - val_accuracy: 0.6102 - val_loss: 0.7185 - learning_rate: 2.0000e-05
# Epoch 33/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 193ms/step - accuracy: 0.6672 - loss: 0.6461 - val_accuracy: 0.6107 - val_loss: 0.7193 - learning_rate: 2.0000e-05
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step
#
# Fold 2 Results:
# Accuracy: 0.6011
# Balanced Accuracy: 0.6020
# MCC: 0.2036
# Sensitivity: 0.5883
# Specificity: 0.6157
#
# Fold 3/5
# Epoch 1/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 34s 208ms/step - accuracy: 0.5148 - loss: 8.7889 - val_accuracy: 0.5548 - val_loss: 6.2277 - learning_rate: 5.0000e-04
# Epoch 2/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5338 - loss: 5.7054 - val_accuracy: 0.5876 - val_loss: 4.1224 - learning_rate: 5.0000e-04
# Epoch 3/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5400 - loss: 3.8281 - val_accuracy: 0.5819 - val_loss: 2.8952 - learning_rate: 5.0000e-04
# Epoch 4/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5425 - loss: 2.7442 - val_accuracy: 0.5977 - val_loss: 2.1951 - learning_rate: 5.0000e-04
# Epoch 5/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.5607 - loss: 2.1172 - val_accuracy: 0.5853 - val_loss: 1.7772 - learning_rate: 5.0000e-04
# Epoch 6/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5618 - loss: 1.7328 - val_accuracy: 0.5983 - val_loss: 1.4764 - learning_rate: 5.0000e-04
# Epoch 7/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.5615 - loss: 1.4546 - val_accuracy: 0.5910 - val_loss: 1.2744 - learning_rate: 5.0000e-04
# Epoch 8/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 22s 197ms/step - accuracy: 0.5767 - loss: 1.2535 - val_accuracy: 0.6000 - val_loss: 1.1277 - learning_rate: 5.0000e-04
# Epoch 9/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5837 - loss: 1.1104 - val_accuracy: 0.6000 - val_loss: 1.0234 - learning_rate: 5.0000e-04
# Epoch 10/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.5837 - loss: 1.0191 - val_accuracy: 0.5989 - val_loss: 0.9590 - learning_rate: 5.0000e-04
# Epoch 11/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.6035 - loss: 0.9394 - val_accuracy: 0.6034 - val_loss: 0.8865 - learning_rate: 5.0000e-04
# Epoch 12/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.6142 - loss: 0.8830 - val_accuracy: 0.6096 - val_loss: 0.8417 - learning_rate: 5.0000e-04
# Epoch 13/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6005 - loss: 0.8385 - val_accuracy: 0.6073 - val_loss: 0.8119 - learning_rate: 5.0000e-04
# Epoch 14/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6090 - loss: 0.8129 - val_accuracy: 0.6119 - val_loss: 0.7836 - learning_rate: 5.0000e-04
# Epoch 15/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.6064 - loss: 0.7931 - val_accuracy: 0.6068 - val_loss: 0.7751 - learning_rate: 5.0000e-04
# Epoch 16/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.6071 - loss: 0.7717 - val_accuracy: 0.6203 - val_loss: 0.7540 - learning_rate: 5.0000e-04
# Epoch 17/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.6197 - loss: 0.7529 - val_accuracy: 0.6045 - val_loss: 0.7441 - learning_rate: 5.0000e-04
# Epoch 18/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.6162 - loss: 0.7382 - val_accuracy: 0.6141 - val_loss: 0.7277 - learning_rate: 5.0000e-04
# Epoch 19/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 190ms/step - accuracy: 0.6192 - loss: 0.7312 - val_accuracy: 0.6158 - val_loss: 0.7241 - learning_rate: 5.0000e-04
# Epoch 20/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6276 - loss: 0.7225 - val_accuracy: 0.6096 - val_loss: 0.7264 - learning_rate: 5.0000e-04
# Epoch 21/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6228 - loss: 0.7172 - val_accuracy: 0.6169 - val_loss: 0.7174 - learning_rate: 5.0000e-04
# Epoch 22/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6245 - loss: 0.7035 - val_accuracy: 0.6113 - val_loss: 0.7057 - learning_rate: 5.0000e-04
# Epoch 23/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.6218 - loss: 0.7043 - val_accuracy: 0.6175 - val_loss: 0.7038 - learning_rate: 5.0000e-04
# Epoch 24/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6286 - loss: 0.7024 - val_accuracy: 0.6102 - val_loss: 0.6991 - learning_rate: 5.0000e-04
# Epoch 25/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6239 - loss: 0.7037 - val_accuracy: 0.6186 - val_loss: 0.6994 - learning_rate: 5.0000e-04
# Epoch 26/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6200 - loss: 0.6982 - val_accuracy: 0.6068 - val_loss: 0.7101 - learning_rate: 5.0000e-04
# Epoch 27/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.6219 - loss: 0.6950 - val_accuracy: 0.6073 - val_loss: 0.7061 - learning_rate: 5.0000e-04
# Epoch 28/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6428 - loss: 0.6865 - val_accuracy: 0.6085 - val_loss: 0.7030 - learning_rate: 1.0000e-04
# Epoch 29/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.6557 - loss: 0.6740 - val_accuracy: 0.6136 - val_loss: 0.7011 - learning_rate: 1.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step
#
# Fold 3 Results:
# Accuracy: 0.6102
# Balanced Accuracy: 0.6091
# MCC: 0.2252
# Sensitivity: 0.7324
# Specificity: 0.4857
#
# Fold 4/5
# Epoch 1/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 32s 208ms/step - accuracy: 0.5205 - loss: 8.8889 - val_accuracy: 0.5616 - val_loss: 6.4165 - learning_rate: 5.0000e-04
# Epoch 2/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.5409 - loss: 5.9420 - val_accuracy: 0.5819 - val_loss: 4.3987 - learning_rate: 5.0000e-04
# Epoch 3/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5326 - loss: 4.1218 - val_accuracy: 0.5593 - val_loss: 3.1742 - learning_rate: 5.0000e-04
# Epoch 4/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.5428 - loss: 3.0144 - val_accuracy: 0.5718 - val_loss: 2.4245 - learning_rate: 5.0000e-04
# Epoch 5/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5668 - loss: 2.3259 - val_accuracy: 0.5785 - val_loss: 1.9455 - learning_rate: 5.0000e-04
# Epoch 6/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5571 - loss: 1.8905 - val_accuracy: 0.5797 - val_loss: 1.6196 - learning_rate: 5.0000e-04
# Epoch 7/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.5862 - loss: 1.5723 - val_accuracy: 0.5960 - val_loss: 1.3808 - learning_rate: 5.0000e-04
# Epoch 8/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.5740 - loss: 1.3613 - val_accuracy: 0.5932 - val_loss: 1.2130 - learning_rate: 5.0000e-04
# Epoch 9/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5776 - loss: 1.1972 - val_accuracy: 0.5881 - val_loss: 1.0919 - learning_rate: 5.0000e-04
# Epoch 10/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.5905 - loss: 1.0711 - val_accuracy: 0.5842 - val_loss: 1.0004 - learning_rate: 5.0000e-04
# Epoch 11/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.5891 - loss: 0.9899 - val_accuracy: 0.5944 - val_loss: 0.9314 - learning_rate: 5.0000e-04
# Epoch 12/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.5966 - loss: 0.9190 - val_accuracy: 0.5927 - val_loss: 0.8774 - learning_rate: 5.0000e-04
# Epoch 13/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6052 - loss: 0.8693 - val_accuracy: 0.5887 - val_loss: 0.8458 - learning_rate: 5.0000e-04
# Epoch 14/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6110 - loss: 0.8293 - val_accuracy: 0.5825 - val_loss: 0.8178 - learning_rate: 5.0000e-04
# Epoch 15/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6078 - loss: 0.8002 - val_accuracy: 0.5831 - val_loss: 0.8086 - learning_rate: 5.0000e-04
# Epoch 16/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6072 - loss: 0.7808 - val_accuracy: 0.5847 - val_loss: 0.7820 - learning_rate: 5.0000e-04
# Epoch 17/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6171 - loss: 0.7618 - val_accuracy: 0.6073 - val_loss: 0.7592 - learning_rate: 5.0000e-04
# Epoch 18/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6169 - loss: 0.7477 - val_accuracy: 0.5972 - val_loss: 0.7508 - learning_rate: 5.0000e-04
# Epoch 19/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6171 - loss: 0.7355 - val_accuracy: 0.5876 - val_loss: 0.7498 - learning_rate: 5.0000e-04
# Epoch 20/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6119 - loss: 0.7277 - val_accuracy: 0.5842 - val_loss: 0.7408 - learning_rate: 5.0000e-04
# Epoch 21/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 190ms/step - accuracy: 0.6143 - loss: 0.7193 - val_accuracy: 0.6073 - val_loss: 0.7365 - learning_rate: 5.0000e-04
# Epoch 22/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6202 - loss: 0.7151 - val_accuracy: 0.5870 - val_loss: 0.7327 - learning_rate: 5.0000e-04
# Epoch 23/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6174 - loss: 0.7134 - val_accuracy: 0.5994 - val_loss: 0.7262 - learning_rate: 5.0000e-04
# Epoch 24/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.6234 - loss: 0.7055 - val_accuracy: 0.6034 - val_loss: 0.7159 - learning_rate: 5.0000e-04
# Epoch 25/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6221 - loss: 0.7026 - val_accuracy: 0.6011 - val_loss: 0.7228 - learning_rate: 5.0000e-04
# Epoch 26/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6216 - loss: 0.7021 - val_accuracy: 0.5819 - val_loss: 0.7242 - learning_rate: 5.0000e-04
# Epoch 27/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6278 - loss: 0.6985 - val_accuracy: 0.5887 - val_loss: 0.7204 - learning_rate: 5.0000e-04
# Epoch 28/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6296 - loss: 0.6897 - val_accuracy: 0.6062 - val_loss: 0.7156 - learning_rate: 1.0000e-04
# Epoch 29/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6437 - loss: 0.6792 - val_accuracy: 0.6045 - val_loss: 0.7154 - learning_rate: 1.0000e-04
# Epoch 30/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6553 - loss: 0.6654 - val_accuracy: 0.6096 - val_loss: 0.7180 - learning_rate: 1.0000e-04
# Epoch 31/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6602 - loss: 0.6600 - val_accuracy: 0.6040 - val_loss: 0.7183 - learning_rate: 1.0000e-04
# Epoch 32/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6573 - loss: 0.6570 - val_accuracy: 0.6090 - val_loss: 0.7145 - learning_rate: 1.0000e-04
# Epoch 33/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.6609 - loss: 0.6539 - val_accuracy: 0.6113 - val_loss: 0.7141 - learning_rate: 1.0000e-04
# Epoch 34/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6727 - loss: 0.6440 - val_accuracy: 0.6090 - val_loss: 0.7207 - learning_rate: 1.0000e-04
# Epoch 35/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6718 - loss: 0.6384 - val_accuracy: 0.6045 - val_loss: 0.7235 - learning_rate: 1.0000e-04
# Epoch 36/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 22s 197ms/step - accuracy: 0.6690 - loss: 0.6396 - val_accuracy: 0.6136 - val_loss: 0.7189 - learning_rate: 1.0000e-04
# Epoch 37/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6806 - loss: 0.6305 - val_accuracy: 0.6136 - val_loss: 0.7200 - learning_rate: 2.0000e-05
# Epoch 38/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 193ms/step - accuracy: 0.6875 - loss: 0.6251 - val_accuracy: 0.6073 - val_loss: 0.7219 - learning_rate: 2.0000e-05
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step
#
# Fold 4 Results:
# Accuracy: 0.6113
# Balanced Accuracy: 0.6115
# MCC: 0.2235
# Sensitivity: 0.6439
# Specificity: 0.5791
#
# Fold 5/5
# Epoch 1/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 32s 205ms/step - accuracy: 0.5190 - loss: 8.9204 - val_accuracy: 0.5254 - val_loss: 6.5381 - learning_rate: 5.0000e-04
# Epoch 2/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.5203 - loss: 6.0521 - val_accuracy: 0.5446 - val_loss: 4.5007 - learning_rate: 5.0000e-04
# Epoch 3/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.5460 - loss: 4.2050 - val_accuracy: 0.5729 - val_loss: 3.2836 - learning_rate: 5.0000e-04
# Epoch 4/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.5695 - loss: 3.0755 - val_accuracy: 0.5655 - val_loss: 2.5013 - learning_rate: 5.0000e-04
# Epoch 5/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.5650 - loss: 2.3836 - val_accuracy: 0.5763 - val_loss: 2.0050 - learning_rate: 5.0000e-04
# Epoch 6/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.5697 - loss: 1.9376 - val_accuracy: 0.5605 - val_loss: 1.6753 - learning_rate: 5.0000e-04
# Epoch 7/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.5680 - loss: 1.6329 - val_accuracy: 0.5667 - val_loss: 1.4475 - learning_rate: 5.0000e-04
# Epoch 8/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.5819 - loss: 1.3938 - val_accuracy: 0.5695 - val_loss: 1.2663 - learning_rate: 5.0000e-04
# Epoch 9/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.5846 - loss: 1.2357 - val_accuracy: 0.5554 - val_loss: 1.1546 - learning_rate: 5.0000e-04
# Epoch 10/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.5839 - loss: 1.1045 - val_accuracy: 0.5734 - val_loss: 1.0387 - learning_rate: 5.0000e-04
# Epoch 11/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5951 - loss: 1.0096 - val_accuracy: 0.5627 - val_loss: 1.0008 - learning_rate: 5.0000e-04
# Epoch 12/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.5985 - loss: 0.9454 - val_accuracy: 0.5565 - val_loss: 0.9415 - learning_rate: 5.0000e-04
# Epoch 13/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6082 - loss: 0.8938 - val_accuracy: 0.5927 - val_loss: 0.8728 - learning_rate: 5.0000e-04
# Epoch 14/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.6122 - loss: 0.8497 - val_accuracy: 0.5780 - val_loss: 0.8427 - learning_rate: 5.0000e-04
# Epoch 15/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6213 - loss: 0.8154 - val_accuracy: 0.5808 - val_loss: 0.8182 - learning_rate: 5.0000e-04
# Epoch 16/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.6247 - loss: 0.7882 - val_accuracy: 0.5921 - val_loss: 0.8020 - learning_rate: 5.0000e-04
# Epoch 17/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6198 - loss: 0.7710 - val_accuracy: 0.5972 - val_loss: 0.7803 - learning_rate: 5.0000e-04
# Epoch 18/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6259 - loss: 0.7539 - val_accuracy: 0.5847 - val_loss: 0.7683 - learning_rate: 5.0000e-04
# Epoch 19/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6222 - loss: 0.7420 - val_accuracy: 0.5927 - val_loss: 0.7559 - learning_rate: 5.0000e-04
# Epoch 20/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.6150 - loss: 0.7343 - val_accuracy: 0.5746 - val_loss: 0.7652 - learning_rate: 5.0000e-04
# Epoch 21/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6177 - loss: 0.7246 - val_accuracy: 0.5661 - val_loss: 0.7593 - learning_rate: 5.0000e-04
# Epoch 22/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6213 - loss: 0.7205 - val_accuracy: 0.5870 - val_loss: 0.7377 - learning_rate: 5.0000e-04
# Epoch 23/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.6277 - loss: 0.7083 - val_accuracy: 0.5706 - val_loss: 0.7428 - learning_rate: 5.0000e-04
# Epoch 24/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - accuracy: 0.6170 - loss: 0.7076 - val_accuracy: 0.5712 - val_loss: 0.7438 - learning_rate: 5.0000e-04
# Epoch 25/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 190ms/step - accuracy: 0.6288 - loss: 0.6995 - val_accuracy: 0.5842 - val_loss: 0.7263 - learning_rate: 5.0000e-04
# Epoch 26/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.6249 - loss: 0.6970 - val_accuracy: 0.5785 - val_loss: 0.7381 - learning_rate: 5.0000e-04
# Epoch 27/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1031s 9s/step - accuracy: 0.6299 - loss: 0.6945 - val_accuracy: 0.5910 - val_loss: 0.7242 - learning_rate: 5.0000e-04
# Epoch 28/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.6308 - loss: 0.6881 - val_accuracy: 0.5831 - val_loss: 0.7379 - learning_rate: 5.0000e-04
# Epoch 29/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.6347 - loss: 0.6915 - val_accuracy: 0.5797 - val_loss: 0.7274 - learning_rate: 5.0000e-04
# Epoch 30/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.6394 - loss: 0.6861 - val_accuracy: 0.5757 - val_loss: 0.7259 - learning_rate: 5.0000e-04
# Epoch 31/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.6461 - loss: 0.6805 - val_accuracy: 0.5819 - val_loss: 0.7229 - learning_rate: 1.0000e-04
# Epoch 32/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.6531 - loss: 0.6690 - val_accuracy: 0.5932 - val_loss: 0.7227 - learning_rate: 1.0000e-04
# Epoch 33/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.6632 - loss: 0.6610 - val_accuracy: 0.5921 - val_loss: 0.7204 - learning_rate: 1.0000e-04
# Epoch 34/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.6668 - loss: 0.6531 - val_accuracy: 0.5780 - val_loss: 0.7290 - learning_rate: 1.0000e-04
# Epoch 35/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.6637 - loss: 0.6489 - val_accuracy: 0.5842 - val_loss: 0.7355 - learning_rate: 1.0000e-04
# Epoch 36/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - accuracy: 0.6757 - loss: 0.6431 - val_accuracy: 0.5864 - val_loss: 0.7364 - learning_rate: 1.0000e-04
# Epoch 37/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - accuracy: 0.6721 - loss: 0.6410 - val_accuracy: 0.5966 - val_loss: 0.7332 - learning_rate: 2.0000e-05
# Epoch 38/50
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - accuracy: 0.6799 - loss: 0.6314 - val_accuracy: 0.5944 - val_loss: 0.7367 - learning_rate: 2.0000e-05
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step
#
# Fold 5 Results:
# Accuracy: 0.5921
# Balanced Accuracy: 0.5925
# MCC: 0.1848
# Sensitivity: 0.5819
# Specificity: 0.6030
#
# Average Cross-validation Results:
# ACC: 0.6099 ± 0.0143
# BALANCED_ACC: 0.6088 ± 0.0120
# MCC: 0.2194 ± 0.0251
# SN: 0.6489 ± 0.0593
# SP: 0.5686 ± 0.0457
#
# Final Test Set Results:
# Accuracy: 0.6131
# Balanced Accuracy: 0.6147
# MCC: 0.1321
# Sensitivity: 0.6167
# Specificity: 0.6127
# Confusion Matrix:
# [[1530  967]
#  [  92  148]]
