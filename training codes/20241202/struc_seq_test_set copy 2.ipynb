# %% [markdown]
# Try with complicated model

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, matthews_corrcoef, accuracy_score, balanced_accuracy_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
import random

# %%
# Set random seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.keras.utils.set_random_seed(SEED)  # This sets all random seeds in keras
tf.config.experimental.enable_op_determinism()  # For complete reproducibility

# %%
def prepare_sequence_data(df):
    """Convert sequences to integer encoding"""
    alphabet = 'ARNDCQEGHILKMFPSTWYV-'
    char_to_int = dict((c, i) for i, c in enumerate(alphabet))
    
    sequences = df['sequence'].values
    encodings = []
    
    for seq in sequences:
        try:
            integer_encoded = [char_to_int[char] for char in seq]
            encodings.append(integer_encoded)
        except Exception as e:
            print(f"Error processing sequence: {e}")
            continue
    
    return np.array(encodings)

# %%
def prepare_structure_data(df):
    """Enhanced feature preparation with better normalization"""
    
    # Normalize angles to their circular nature
    def normalize_angles(angle_array):
        angle_rad = np.pi * angle_array / 180.0
        return np.stack([np.sin(angle_rad), np.cos(angle_rad)], axis=-1)
    
    # Process each feature type
    features_list = []
    
    # 1. Process angles (phi, psi, omega, tau)
    angles = ['phi', 'psi', 'omega', 'tau']
    for angle in angles:
        # Convert string to array
        angle_arrays = np.array([np.array(eval(x)) for x in df[angle]])
        # Get sin/cos representations
        angle_features = normalize_angles(angle_arrays)
        features_list.append(angle_features)
    
    # 2. Process SASA
    sasa_arrays = np.array([np.array(eval(x)) for x in df['sasa']])
    scaler = RobustScaler()
    sasa_flat = sasa_arrays.reshape(-1, 1)
    sasa_scaled = scaler.fit_transform(sasa_flat).reshape(sasa_arrays.shape)
    features_list.append(sasa_scaled[..., np.newaxis])
    
    # 3. Process secondary structure
    ss_arrays = np.array([list(seq) for seq in df['ss']])
    ss_encoded = np.zeros((len(ss_arrays), ss_arrays.shape[1], 3))
    ss_map = {'H': 0, 'E': 1, 'L': 2}
    for i in range(len(ss_arrays)):
        for j in range(len(ss_arrays[i])):
            ss_encoded[i, j, ss_map[ss_arrays[i, j]]] = 1
    features_list.append(ss_encoded)
    
    # Combine all features
    features = np.concatenate(features_list, axis=-1)
    
    return features

# %%
def create_combined_model(seq_length=33, struct_features=12, struct_window=0):
    # Sequence track - enhanced
    seq_input = tf.keras.layers.Input(shape=(seq_length,), name='sequence_input')
    x_seq = tf.keras.layers.Embedding(21, 32, input_length=seq_length)(seq_input)  # Increased embedding dim
    x_seq = tf.keras.layers.Reshape((seq_length, 32, 1))(x_seq)
    
    # Multi-scale convolutions for sequence
    conv1 = tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same')(x_seq)
    conv2 = tf.keras.layers.Conv2D(32, kernel_size=(5, 3), activation='relu', padding='same')(x_seq)
    conv3 = tf.keras.layers.Conv2D(32, kernel_size=(7, 3), activation='relu', padding='same')(x_seq)
    
    x_seq = tf.keras.layers.Concatenate()([conv1, conv2, conv3])
    x_seq = tf.keras.layers.BatchNormalization()(x_seq)
    x_seq = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x_seq)
    x_seq = tf.keras.layers.Dropout(0.3)(x_seq)
    x_seq = tf.keras.layers.Flatten()(x_seq)
    x_seq = tf.keras.layers.Dense(64, activation='relu')(x_seq)
    x_seq = tf.keras.layers.Dropout(0.3)(x_seq)

    # Structure track - enhanced
    struct_input = tf.keras.layers.Input(shape=(seq_length, struct_features), name='structure_input')
    
    # Extract window around middle position
    middle_pos = seq_length // 2
    if struct_window == 0:
        x_struct = struct_input[:, middle_pos:middle_pos+1, :]
    else:
        x_struct = struct_input[:, middle_pos-struct_window:middle_pos+struct_window+1, :]
    
    # Multi-scale convolutions for structure
    conv_s1 = tf.keras.layers.Conv1D(32, 3, padding='same', activation='relu')(x_struct)
    conv_s2 = tf.keras.layers.Conv1D(32, 5, padding='same', activation='relu')(x_struct)
    
    x_struct = tf.keras.layers.Concatenate()([conv_s1, conv_s2])
    x_struct = tf.keras.layers.BatchNormalization()(x_struct)
    x_struct = tf.keras.layers.GlobalAveragePooling1D()(x_struct)
    x_struct = tf.keras.layers.Dropout(0.3)(x_struct)
    x_struct = tf.keras.layers.Dense(64, activation='relu')(x_struct)
    x_struct = tf.keras.layers.Dropout(0.3)(x_struct)

    # Attention-based combination
    combined = tf.keras.layers.Concatenate()([x_seq, x_struct])
    att = tf.keras.layers.Dense(128, activation='tanh')(combined)
    att = tf.keras.layers.Dense(1, activation='softmax')(att)
    combined = tf.keras.layers.Multiply()([combined, att])
    
    # Final layers with residual connections
    x = tf.keras.layers.Dense(64, activation='relu')(combined)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    
    # Residual connection
    x_res = tf.keras.layers.Dense(64)(x)
    x = tf.keras.layers.Add()([x, x_res])
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    
    outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    
    return tf.keras.Model(inputs=[seq_input, struct_input], outputs=outputs)

# %%
def print_metrics_with_cm(y_true, y_pred, phase=""):
    """Helper function to print metrics and confusion matrix"""
    cm = confusion_matrix(y_true, y_pred)
    
    print(f"\n{phase} Results:")
    print(f"Accuracy: {accuracy_score(y_true, y_pred):.4f}")
    print(f"Balanced Accuracy: {balanced_accuracy_score(y_true, y_pred):.4f}")
    print(f"MCC: {matthews_corrcoef(y_true, y_pred):.4f}")
    print(f"Sensitivity: {cm[1][1]/(cm[1][1]+cm[1][0]):.4f}")
    print(f"Specificity: {cm[0][0]/(cm[0][0]+cm[0][1]):.4f}")
    print("Confusion Matrix:")
    print(f"TN: {cm[0][0]}, FP: {cm[0][1]}")
    print(f"FN: {cm[1][0]}, TP: {cm[1][1]}")
    print("\nConfusion Matrix Format:")
    print(cm)
    
    return cm

# %%
def train_and_evaluate(struct_window=0):
    """Training function with proper validation and test set handling"""
    # Load data
    print("Loading data...")
    train_df = pd.read_csv("../data/processed_data_train_after.csv")
    test_df = pd.read_csv("../data/processed_data_test_after.csv")
    
    # Prepare data
    X_train_seq = prepare_sequence_data(train_df)
    X_test_seq = prepare_sequence_data(test_df)
    X_train_struct = prepare_structure_data(train_df)
    X_test_struct = prepare_structure_data(test_df)
    
    y_train = train_df['label'].values
    y_test = test_df['label'].values
    
    # Print class distribution
    print("\nTraining set distribution:")
    print(train_df['label'].value_counts())
    print("\nTest set distribution:")
    print(test_df['label'].value_counts())
    
    # Calculate class weights
    total_samples = len(y_train)
    pos_samples = np.sum(y_train == 1)
    neg_samples = np.sum(y_train == 0)
    
    class_weights = {
        0: total_samples / (2 * neg_samples),
        1: total_samples / (2 * pos_samples)
    }
    
    # Cross-validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=42)
    metrics = {'acc': [], 'balanced_acc': [], 'mcc': [], 'sn': [], 'sp': []}
    best_weights = None
    best_val_mcc = -1
    
    for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train_seq), 1):
        print(f"\n{'='*50}")
        print(f"Fold {fold}/5")
        print('='*50)
        
        # Callbacks
        callbacks = [
            tf.keras.callbacks.EarlyStopping(
                monitor='val_loss',
                patience=5,
                restore_best_weights=True
            ),
            tf.keras.callbacks.ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=3,
                min_lr=1e-6
            )
        ]
        
        # Create and compile model
        model = create_combined_model(
            seq_length=33,
            struct_features=X_train_struct.shape[2],
            struct_window=struct_window
        )
        
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
            loss='binary_crossentropy',
            metrics=['accuracy']
        )
        
        # Train model
        history = model.fit(
            [X_train_seq[train_idx], X_train_struct[train_idx]], 
            y_train[train_idx],
            validation_data=(
                [X_train_seq[val_idx], X_train_struct[val_idx]], 
                y_train[val_idx]
            ),
            batch_size=32,
            epochs=50,
            callbacks=callbacks,
            class_weight=class_weights,
            verbose=1
        )
        
        # Plot training history
        plt.figure(figsize=(10, 6))
        plt.plot(history.history['accuracy'], label='Train Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title(f'Model Accuracy - Fold {fold}')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()
        plt.show()
        
        # Evaluate on validation set
        y_pred = model.predict([X_train_seq[val_idx], X_train_struct[val_idx]])
        y_pred_binary = (y_pred > 0.5).astype(int)
        
        # Calculate metrics and print confusion matrix
        cm = print_metrics_with_cm(y_train[val_idx], y_pred_binary, f"Fold {fold} Validation")
        
        # Store metrics
        curr_mcc = matthews_corrcoef(y_train[val_idx], y_pred_binary)
        metrics['acc'].append(accuracy_score(y_train[val_idx], y_pred_binary))
        metrics['balanced_acc'].append(balanced_accuracy_score(y_train[val_idx], y_pred_binary))
        metrics['mcc'].append(curr_mcc)
        metrics['sn'].append(cm[1][1]/(cm[1][1]+cm[1][0]))
        metrics['sp'].append(cm[0][0]/(cm[0][0]+cm[0][1]))
        
        # Save best weights based on validation MCC
        if curr_mcc > best_val_mcc:
            best_val_mcc = curr_mcc
            best_weights = model.get_weights()
            print(f"\nNew best weights saved! (MCC: {curr_mcc:.4f})")
    
    print("\n" + "="*50)
    print("Cross-validation Complete")
    print("="*50)
    
    # Print average cross-validation results
    print("\nAverage Cross-validation Results:")
    for metric in metrics:
        print(f"{metric.upper()}: {np.mean(metrics[metric]):.4f} ± {np.std(metrics[metric]):.4f}")
    
    # Create final model with best weights
    final_model = create_combined_model(
        seq_length=33,
        struct_features=X_train_struct.shape[2],
        struct_window=struct_window
    )
    final_model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    final_model.set_weights(best_weights)
    
    # Evaluate best model on test set
    print("\n" + "="*50)
    print("Final Test Set Evaluation (Best Model)")
    print("="*50)
    
    test_pred = final_model.predict([X_test_seq, X_test_struct])
    test_pred_binary = (test_pred > 0.5).astype(int)
    cm_test = print_metrics_with_cm(y_test, test_pred_binary, "Test Set")
    
    # Save final model
    try:
        final_model.save('best_model')
        print("\nBest model saved as 'best_model'")
    except Exception as e:
        print(f"\nWarning: Could not save model. Error: {str(e)}")
        print("Continuing without saving model...")
    
    return final_model

# %%
if __name__ == "__main__":
    model = train_and_evaluate()
# Out:
# Loading data...
#
# Training set distribution:
# label
# 1    4592
# 0    4258
# Name: count, dtype: int64
#
# Test set distribution:
# label
# 0    2497
# 1     240
# Name: count, dtype: int64
#
# ==================================================
# Fold 1/5
# ==================================================
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2024-12-03 03:14:14.279670: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-12-03 03:14:14.279690: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-12-03 03:14:14.279695: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-12-03 03:14:14.279711: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-03 03:14:14.279721: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 2024-12-03 03:14:15.605293: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 114ms/step - accuracy: 0.5080 - loss: 0.8926 - val_accuracy: 0.5158 - val_loss: 0.6935 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.5141 - loss: 0.7595 - val_accuracy: 0.5158 - val_loss: 0.6986 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 116ms/step - accuracy: 0.5188 - loss: 0.7217 - val_accuracy: 0.5158 - val_loss: 0.7135 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.5532 - loss: 0.6965 - val_accuracy: 0.5136 - val_loss: 0.7518 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.6135 - loss: 0.6486 - val_accuracy: 0.5379 - val_loss: 0.7291 - learning_rate: 5.0000e-04
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 23s 106ms/step - accuracy: 0.6378 - loss: 0.6369 - val_accuracy: 0.5814 - val_loss: 0.6738 - learning_rate: 5.0000e-04
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 23s 106ms/step - accuracy: 0.6731 - loss: 0.6099 - val_accuracy: 0.6203 - val_loss: 0.6469 - learning_rate: 5.0000e-04
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.7036 - loss: 0.5717 - val_accuracy: 0.6130 - val_loss: 0.6485 - learning_rate: 5.0000e-04
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.7472 - loss: 0.5277 - val_accuracy: 0.6593 - val_loss: 0.6194 - learning_rate: 5.0000e-04
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.7881 - loss: 0.4682 - val_accuracy: 0.6271 - val_loss: 0.6950 - learning_rate: 5.0000e-04
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.8259 - loss: 0.4088 - val_accuracy: 0.6915 - val_loss: 0.6442 - learning_rate: 5.0000e-04
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.8691 - loss: 0.3191 - val_accuracy: 0.6932 - val_loss: 0.6768 - learning_rate: 5.0000e-04
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.9168 - loss: 0.2277 - val_accuracy: 0.6763 - val_loss: 0.7529 - learning_rate: 2.5000e-04
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.9369 - loss: 0.1849 - val_accuracy: 0.6859 - val_loss: 0.7855 - learning_rate: 2.5000e-04
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (32, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
#
# Fold 1 Validation Results:
# Accuracy: 0.6593
# Balanced Accuracy: 0.6506
# MCC: 0.3632
# Sensitivity: 0.9255
# Specificity: 0.3757
# Confusion Matrix:
# TN: 322, FP: 535
# FN: 68, TP: 845
#
# Confusion Matrix Format:
# [[322 535]
#  [ 68 845]]
#
# New best weights saved! (MCC: 0.3632)
#
# ==================================================
# Fold 2/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - accuracy: 0.5012 - loss: 0.8609 - val_accuracy: 0.5288 - val_loss: 0.6912 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.4988 - loss: 0.7592 - val_accuracy: 0.4718 - val_loss: 0.6966 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.5162 - loss: 0.7226 - val_accuracy: 0.4712 - val_loss: 0.7362 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 23s 105ms/step - accuracy: 0.5533 - loss: 0.6939 - val_accuracy: 0.5531 - val_loss: 0.6805 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 23s 105ms/step - accuracy: 0.5988 - loss: 0.6657 - val_accuracy: 0.6554 - val_loss: 0.6377 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 23s 105ms/step - accuracy: 0.6253 - loss: 0.6551 - val_accuracy: 0.5994 - val_loss: 0.6547 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 23s 106ms/step - accuracy: 0.6311 - loss: 0.6364 - val_accuracy: 0.5215 - val_loss: 0.7160 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.6748 - loss: 0.6060 - val_accuracy: 0.6588 - val_loss: 0.6074 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.6919 - loss: 0.5874 - val_accuracy: 0.7034 - val_loss: 0.5756 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.7039 - loss: 0.5712 - val_accuracy: 0.6316 - val_loss: 0.6393 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.7380 - loss: 0.5385 - val_accuracy: 0.6130 - val_loss: 0.7005 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 23s 105ms/step - accuracy: 0.7616 - loss: 0.5034 - val_accuracy: 0.7040 - val_loss: 0.5991 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.8037 - loss: 0.4496 - val_accuracy: 0.7000 - val_loss: 0.6009 - learning_rate: 5.0000e-04
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.8482 - loss: 0.3620 - val_accuracy: 0.6661 - val_loss: 0.7161 - learning_rate: 5.0000e-04
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (32, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
#
# Fold 2 Validation Results:
# Accuracy: 0.7034
# Balanced Accuracy: 0.7024
# MCC: 0.4048
# Sensitivity: 0.7201
# Specificity: 0.6847
# Confusion Matrix:
# TN: 571, FP: 263
# FN: 262, TP: 674
#
# Confusion Matrix Format:
# [[571 263]
#  [262 674]]
#
# New best weights saved! (MCC: 0.4048)
#
# ==================================================
# Fold 3/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 113ms/step - accuracy: 0.5191 - loss: 0.8725 - val_accuracy: 0.5158 - val_loss: 0.8105 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 23s 105ms/step - accuracy: 0.5374 - loss: 0.7432 - val_accuracy: 0.5147 - val_loss: 0.8229 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 23s 105ms/step - accuracy: 0.5579 - loss: 0.7122 - val_accuracy: 0.6288 - val_loss: 0.6521 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 23s 106ms/step - accuracy: 0.6136 - loss: 0.6602 - val_accuracy: 0.5599 - val_loss: 0.7164 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.6692 - loss: 0.6106 - val_accuracy: 0.6006 - val_loss: 0.6954 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 23s 106ms/step - accuracy: 0.6954 - loss: 0.5805 - val_accuracy: 0.6486 - val_loss: 0.6331 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.7226 - loss: 0.5499 - val_accuracy: 0.5757 - val_loss: 0.7637 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.7542 - loss: 0.5167 - val_accuracy: 0.6305 - val_loss: 0.6856 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.7811 - loss: 0.4756 - val_accuracy: 0.6684 - val_loss: 0.6870 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.8244 - loss: 0.3949 - val_accuracy: 0.6486 - val_loss: 0.7709 - learning_rate: 5.0000e-04
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.8658 - loss: 0.3192 - val_accuracy: 0.6780 - val_loss: 0.7648 - learning_rate: 5.0000e-04
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (32, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
#
# Fold 3 Validation Results:
# Accuracy: 0.6486
# Balanced Accuracy: 0.6391
# MCC: 0.3502
# Sensitivity: 0.9387
# Specificity: 0.3396
# Confusion Matrix:
# TN: 291, FP: 566
# FN: 56, TP: 857
#
# Confusion Matrix Format:
# [[291 566]
#  [ 56 857]]
#
# ==================================================
# Fold 4/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 31s 111ms/step - accuracy: 0.5061 - loss: 0.8404 - val_accuracy: 0.4842 - val_loss: 0.7398 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.5197 - loss: 0.7359 - val_accuracy: 0.4802 - val_loss: 0.8222 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.6021 - loss: 0.6650 - val_accuracy: 0.4842 - val_loss: 0.8569 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.6421 - loss: 0.6381 - val_accuracy: 0.5616 - val_loss: 0.6851 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.6716 - loss: 0.6126 - val_accuracy: 0.6938 - val_loss: 0.5913 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.6953 - loss: 0.5855 - val_accuracy: 0.6446 - val_loss: 0.6671 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.7250 - loss: 0.5454 - val_accuracy: 0.6650 - val_loss: 0.6207 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.7627 - loss: 0.4982 - val_accuracy: 0.7045 - val_loss: 0.5962 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.8179 - loss: 0.4158 - val_accuracy: 0.7198 - val_loss: 0.6158 - learning_rate: 5.0000e-04
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.8586 - loss: 0.3399 - val_accuracy: 0.7040 - val_loss: 0.6309 - learning_rate: 5.0000e-04
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (32, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
#
# Fold 4 Validation Results:
# Accuracy: 0.6938
# Balanced Accuracy: 0.6953
# MCC: 0.3919
# Sensitivity: 0.6462
# Specificity: 0.7445
# Confusion Matrix:
# TN: 638, FP: 219
# FN: 323, TP: 590
#
# Confusion Matrix Format:
# [[638 219]
#  [323 590]]
#
# ==================================================
# Fold 5/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - accuracy: 0.5045 - loss: 0.9134 - val_accuracy: 0.5181 - val_loss: 0.6953 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 23s 105ms/step - accuracy: 0.5121 - loss: 0.7791 - val_accuracy: 0.5181 - val_loss: 0.6961 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.5114 - loss: 0.7417 - val_accuracy: 0.5181 - val_loss: 0.7120 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.5532 - loss: 0.7023 - val_accuracy: 0.5175 - val_loss: 0.7276 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 23s 106ms/step - accuracy: 0.5924 - loss: 0.6799 - val_accuracy: 0.5418 - val_loss: 0.7067 - learning_rate: 5.0000e-04
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 115ms/step - accuracy: 0.6346 - loss: 0.6467 - val_accuracy: 0.6621 - val_loss: 0.6193 - learning_rate: 5.0000e-04
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 108ms/step - accuracy: 0.6594 - loss: 0.6206 - val_accuracy: 0.5921 - val_loss: 0.6558 - learning_rate: 5.0000e-04
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 108ms/step - accuracy: 0.6980 - loss: 0.5845 - val_accuracy: 0.5808 - val_loss: 0.6878 - learning_rate: 5.0000e-04
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.7264 - loss: 0.5521 - val_accuracy: 0.6757 - val_loss: 0.5889 - learning_rate: 5.0000e-04
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.7558 - loss: 0.5094 - val_accuracy: 0.6915 - val_loss: 0.5750 - learning_rate: 5.0000e-04
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.7842 - loss: 0.4678 - val_accuracy: 0.7062 - val_loss: 0.5638 - learning_rate: 5.0000e-04
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 110ms/step - accuracy: 0.8255 - loss: 0.4070 - val_accuracy: 0.7153 - val_loss: 0.5893 - learning_rate: 5.0000e-04
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 115ms/step - accuracy: 0.8600 - loss: 0.3428 - val_accuracy: 0.7119 - val_loss: 0.6170 - learning_rate: 5.0000e-04
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.8967 - loss: 0.2725 - val_accuracy: 0.7175 - val_loss: 0.6936 - learning_rate: 5.0000e-04
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.9357 - loss: 0.1883 - val_accuracy: 0.6983 - val_loss: 0.7367 - learning_rate: 2.5000e-04
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.9380 - loss: 0.1648 - val_accuracy: 0.7096 - val_loss: 0.7575 - learning_rate: 2.5000e-04
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (32, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
#
# Fold 5 Validation Results:
# Accuracy: 0.7062
# Balanced Accuracy: 0.7000
# MCC: 0.4280
# Sensitivity: 0.8713
# Specificity: 0.5287
# Confusion Matrix:
# TN: 451, FP: 402
# FN: 118, TP: 799
#
# Confusion Matrix Format:
# [[451 402]
#  [118 799]]
#
# New best weights saved! (MCC: 0.4280)
#
# ==================================================
# Cross-validation Complete
# ==================================================
#
# Average Cross-validation Results:
# ACC: 0.6823 ± 0.0237
# BALANCED_ACC: 0.6775 ± 0.0270
# MCC: 0.3876 ± 0.0281
# SN: 0.8204 ± 0.1166
# SP: 0.5346 ± 0.1612
#
# ==================================================
# Final Test Set Evaluation (Best Model)
# ==================================================
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (32, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 78/86 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
#
# Test Set Results:
# Accuracy: 0.5491
# Balanced Accuracy: 0.7134
# MCC: 0.2416
# Sensitivity: 0.9125
# Specificity: 0.5142
# Confusion Matrix:
# TN: 1284, FP: 1213
# FN: 21, TP: 219
#
# Confusion Matrix Format:
# [[1284 1213]
#  [  21  219]]
#
# Warning: Could not save model. Error: Invalid filepath extension for saving. Please add either a `.keras` extension for the native Keras format (recommended) or a `.h5` extension. Use `model.export(filepath)` if you want to export a SavedModel for use with TFLite/TFServing/etc. Received: filepath=best_model.
# Continuing without saving model...

# %%
if __name__ == "__main__":
    model = train_and_evaluate(struct_window=1)
# Out:
# Loading data...
#
# Training set distribution:
# label
# 1    4592
# 0    4258
# Name: count, dtype: int64
#
# Test set distribution:
# label
# 0    2497
# 1     240
# Name: count, dtype: int64
#
# ==================================================
# Fold 1/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.5368 - loss: 0.7069 - val_accuracy: 0.5542 - val_loss: 0.6842 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5345 - loss: 0.6913 - val_accuracy: 0.5695 - val_loss: 0.6722 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5745 - loss: 0.6743 - val_accuracy: 0.6192 - val_loss: 0.6530 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6322 - loss: 0.6492 - val_accuracy: 0.6780 - val_loss: 0.6176 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6847 - loss: 0.5992 - val_accuracy: 0.7458 - val_loss: 0.5458 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7243 - loss: 0.5474 - val_accuracy: 0.7486 - val_loss: 0.5303 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7431 - loss: 0.5286 - val_accuracy: 0.7492 - val_loss: 0.5204 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7575 - loss: 0.5071 - val_accuracy: 0.7525 - val_loss: 0.5155 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7650 - loss: 0.4902 - val_accuracy: 0.7554 - val_loss: 0.5070 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7737 - loss: 0.4770 - val_accuracy: 0.7475 - val_loss: 0.5043 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7947 - loss: 0.4597 - val_accuracy: 0.7486 - val_loss: 0.5104 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7954 - loss: 0.4448 - val_accuracy: 0.7508 - val_loss: 0.5110 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7956 - loss: 0.4388 - val_accuracy: 0.7333 - val_loss: 0.5229 - learning_rate: 0.0010
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8158 - loss: 0.4090 - val_accuracy: 0.7469 - val_loss: 0.5223 - learning_rate: 5.0000e-04
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8313 - loss: 0.3976 - val_accuracy: 0.7520 - val_loss: 0.5358 - learning_rate: 5.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 1 Validation Results:
# Accuracy: 0.7475
# Balanced Accuracy: 0.7447
# MCC: 0.4981
# Sensitivity: 0.8313
# Specificity: 0.6581
# Confusion Matrix:
# TN: 564, FP: 293
# FN: 154, TP: 759
#
# Confusion Matrix Format:
# [[564 293]
#  [154 759]]
#
# New best weights saved! (MCC: 0.4981)
#
# ==================================================
# Fold 2/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.5347 - loss: 0.7142 - val_accuracy: 0.5989 - val_loss: 0.6779 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.5914 - loss: 0.6641 - val_accuracy: 0.6927 - val_loss: 0.5948 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6909 - loss: 0.5885 - val_accuracy: 0.7486 - val_loss: 0.5331 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7260 - loss: 0.5464 - val_accuracy: 0.7475 - val_loss: 0.5140 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7455 - loss: 0.5226 - val_accuracy: 0.7531 - val_loss: 0.5086 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7599 - loss: 0.5059 - val_accuracy: 0.7497 - val_loss: 0.5103 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7636 - loss: 0.4979 - val_accuracy: 0.7616 - val_loss: 0.4960 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7760 - loss: 0.4756 - val_accuracy: 0.7582 - val_loss: 0.4952 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7900 - loss: 0.4577 - val_accuracy: 0.7554 - val_loss: 0.4990 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.7992 - loss: 0.4495 - val_accuracy: 0.7503 - val_loss: 0.5062 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8163 - loss: 0.4186 - val_accuracy: 0.7452 - val_loss: 0.5183 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8289 - loss: 0.3983 - val_accuracy: 0.7497 - val_loss: 0.5247 - learning_rate: 5.0000e-04
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8383 - loss: 0.3740 - val_accuracy: 0.7458 - val_loss: 0.5360 - learning_rate: 5.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 2 Validation Results:
# Accuracy: 0.7582
# Balanced Accuracy: 0.7565
# MCC: 0.5141
# Sensitivity: 0.7863
# Specificity: 0.7266
# Confusion Matrix:
# TN: 606, FP: 228
# FN: 200, TP: 736
#
# Confusion Matrix Format:
# [[606 228]
#  [200 736]]
#
# New best weights saved! (MCC: 0.5141)
#
# ==================================================
# Fold 3/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.5299 - loss: 0.7107 - val_accuracy: 0.5729 - val_loss: 0.6835 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.5499 - loss: 0.6808 - val_accuracy: 0.5864 - val_loss: 0.6730 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.5793 - loss: 0.6741 - val_accuracy: 0.6243 - val_loss: 0.6538 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6305 - loss: 0.6419 - val_accuracy: 0.6621 - val_loss: 0.6194 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6681 - loss: 0.6099 - val_accuracy: 0.6944 - val_loss: 0.5824 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7072 - loss: 0.5714 - val_accuracy: 0.7232 - val_loss: 0.5546 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7303 - loss: 0.5459 - val_accuracy: 0.7266 - val_loss: 0.5488 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7416 - loss: 0.5245 - val_accuracy: 0.7350 - val_loss: 0.5389 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7454 - loss: 0.5189 - val_accuracy: 0.7395 - val_loss: 0.5340 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7629 - loss: 0.4969 - val_accuracy: 0.7362 - val_loss: 0.5417 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7705 - loss: 0.4829 - val_accuracy: 0.7395 - val_loss: 0.5384 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7754 - loss: 0.4712 - val_accuracy: 0.7446 - val_loss: 0.5417 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7913 - loss: 0.4462 - val_accuracy: 0.7441 - val_loss: 0.5433 - learning_rate: 5.0000e-04
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8019 - loss: 0.4280 - val_accuracy: 0.7418 - val_loss: 0.5545 - learning_rate: 5.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 3 Validation Results:
# Accuracy: 0.7395
# Balanced Accuracy: 0.7375
# MCC: 0.4798
# Sensitivity: 0.8028
# Specificity: 0.6721
# Confusion Matrix:
# TN: 576, FP: 281
# FN: 180, TP: 733
#
# Confusion Matrix Format:
# [[576 281]
#  [180 733]]
#
# ==================================================
# Fold 4/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.5204 - loss: 0.7094 - val_accuracy: 0.5780 - val_loss: 0.6840 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.5674 - loss: 0.6756 - val_accuracy: 0.6514 - val_loss: 0.6263 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6546 - loss: 0.6285 - val_accuracy: 0.7040 - val_loss: 0.5856 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7027 - loss: 0.5744 - val_accuracy: 0.7096 - val_loss: 0.5673 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7410 - loss: 0.5361 - val_accuracy: 0.7243 - val_loss: 0.5534 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7588 - loss: 0.5140 - val_accuracy: 0.7390 - val_loss: 0.5368 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7634 - loss: 0.4988 - val_accuracy: 0.7367 - val_loss: 0.5358 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7695 - loss: 0.4872 - val_accuracy: 0.7339 - val_loss: 0.5305 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7830 - loss: 0.4718 - val_accuracy: 0.7271 - val_loss: 0.5379 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7854 - loss: 0.4598 - val_accuracy: 0.7288 - val_loss: 0.5471 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7979 - loss: 0.4452 - val_accuracy: 0.7322 - val_loss: 0.5460 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8080 - loss: 0.4232 - val_accuracy: 0.7463 - val_loss: 0.5287 - learning_rate: 5.0000e-04
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8210 - loss: 0.4042 - val_accuracy: 0.7384 - val_loss: 0.5354 - learning_rate: 5.0000e-04
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8204 - loss: 0.4033 - val_accuracy: 0.7412 - val_loss: 0.5471 - learning_rate: 5.0000e-04
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8362 - loss: 0.3809 - val_accuracy: 0.7390 - val_loss: 0.5493 - learning_rate: 5.0000e-04
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8366 - loss: 0.3737 - val_accuracy: 0.7384 - val_loss: 0.5670 - learning_rate: 2.5000e-04
# Epoch 17/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8419 - loss: 0.3666 - val_accuracy: 0.7401 - val_loss: 0.5669 - learning_rate: 2.5000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 4 Validation Results:
# Accuracy: 0.7463
# Balanced Accuracy: 0.7449
# MCC: 0.4923
# Sensitivity: 0.7908
# Specificity: 0.6989
# Confusion Matrix:
# TN: 599, FP: 258
# FN: 191, TP: 722
#
# Confusion Matrix Format:
# [[599 258]
#  [191 722]]
#
# ==================================================
# Fold 5/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.5105 - loss: 0.7211 - val_accuracy: 0.5463 - val_loss: 0.6865 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.5624 - loss: 0.6805 - val_accuracy: 0.6006 - val_loss: 0.6627 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6342 - loss: 0.6477 - val_accuracy: 0.6638 - val_loss: 0.6107 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6882 - loss: 0.5988 - val_accuracy: 0.6938 - val_loss: 0.5853 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7125 - loss: 0.5640 - val_accuracy: 0.7186 - val_loss: 0.5513 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7371 - loss: 0.5385 - val_accuracy: 0.7316 - val_loss: 0.5346 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7545 - loss: 0.5115 - val_accuracy: 0.7339 - val_loss: 0.5289 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7734 - loss: 0.4915 - val_accuracy: 0.7333 - val_loss: 0.5263 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7761 - loss: 0.4811 - val_accuracy: 0.7339 - val_loss: 0.5325 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7880 - loss: 0.4651 - val_accuracy: 0.7322 - val_loss: 0.5401 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8013 - loss: 0.4541 - val_accuracy: 0.7356 - val_loss: 0.5426 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8149 - loss: 0.4148 - val_accuracy: 0.7350 - val_loss: 0.5397 - learning_rate: 5.0000e-04
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8274 - loss: 0.3999 - val_accuracy: 0.7362 - val_loss: 0.5438 - learning_rate: 5.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 5 Validation Results:
# Accuracy: 0.7333
# Balanced Accuracy: 0.7323
# MCC: 0.4656
# Sensitivity: 0.7601
# Specificity: 0.7046
# Confusion Matrix:
# TN: 601, FP: 252
# FN: 220, TP: 697
#
# Confusion Matrix Format:
# [[601 252]
#  [220 697]]
#
# ==================================================
# Cross-validation Complete
# ==================================================
#
# Average Cross-validation Results:
# ACC: 0.7450 ± 0.0083
# BALANCED_ACC: 0.7432 ± 0.0082
# MCC: 0.4900 ± 0.0165
# SN: 0.7943 ± 0.0232
# SP: 0.6921 ± 0.0243
#
# ==================================================
# Final Test Set Evaluation (Best Model)
# ==================================================
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# Test Set Results:
# Accuracy: 0.7304
# Balanced Accuracy: 0.7487
# MCC: 0.3023
# Sensitivity: 0.7708
# Specificity: 0.7265
# Confusion Matrix:
# TN: 1814, FP: 683
# FN: 55, TP: 185
#
# Confusion Matrix Format:
# [[1814  683]
#  [  55  185]]
#
# Warning: Could not save model. Error: Invalid filepath extension for saving. Please add either a `.keras` extension for the native Keras format (recommended) or a `.h5` extension. Use `model.export(filepath)` if you want to export a SavedModel for use with TFLite/TFServing/etc. Received: filepath=best_model.
# Continuing without saving model...

# %%
if __name__ == "__main__":
    model = train_and_evaluate(struct_window=2)
# Out:
# Loading data...
#
# Training set distribution:
# label
# 1    4592
# 0    4258
# Name: count, dtype: int64
#
# Test set distribution:
# label
# 0    2497
# 1     240
# Name: count, dtype: int64
#
# ==================================================
# Fold 1/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.5253 - loss: 0.7183 - val_accuracy: 0.5842 - val_loss: 0.6760 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5929 - loss: 0.6651 - val_accuracy: 0.6638 - val_loss: 0.6235 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6478 - loss: 0.6334 - val_accuracy: 0.6718 - val_loss: 0.6095 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6723 - loss: 0.6124 - val_accuracy: 0.6983 - val_loss: 0.5943 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6973 - loss: 0.5916 - val_accuracy: 0.6915 - val_loss: 0.5876 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7158 - loss: 0.5660 - val_accuracy: 0.7000 - val_loss: 0.5881 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7268 - loss: 0.5512 - val_accuracy: 0.7243 - val_loss: 0.5541 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7530 - loss: 0.5185 - val_accuracy: 0.7271 - val_loss: 0.5435 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7676 - loss: 0.4931 - val_accuracy: 0.7367 - val_loss: 0.5396 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7787 - loss: 0.4775 - val_accuracy: 0.7237 - val_loss: 0.5441 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7919 - loss: 0.4637 - val_accuracy: 0.7277 - val_loss: 0.5453 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8051 - loss: 0.4413 - val_accuracy: 0.7203 - val_loss: 0.5671 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8160 - loss: 0.4196 - val_accuracy: 0.7226 - val_loss: 0.5746 - learning_rate: 5.0000e-04
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8284 - loss: 0.4055 - val_accuracy: 0.7226 - val_loss: 0.5780 - learning_rate: 5.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 1 Validation Results:
# Accuracy: 0.7367
# Balanced Accuracy: 0.7347
# MCC: 0.4740
# Sensitivity: 0.7985
# Specificity: 0.6709
# Confusion Matrix:
# TN: 575, FP: 282
# FN: 184, TP: 729
#
# Confusion Matrix Format:
# [[575 282]
#  [184 729]]
#
# New best weights saved! (MCC: 0.4740)
#
# ==================================================
# Fold 2/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.5101 - loss: 0.7183 - val_accuracy: 0.5814 - val_loss: 0.6826 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.5579 - loss: 0.6826 - val_accuracy: 0.5921 - val_loss: 0.6712 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.5742 - loss: 0.6756 - val_accuracy: 0.6006 - val_loss: 0.6662 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6032 - loss: 0.6647 - val_accuracy: 0.6384 - val_loss: 0.6317 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6483 - loss: 0.6262 - val_accuracy: 0.6847 - val_loss: 0.5875 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7009 - loss: 0.5813 - val_accuracy: 0.7141 - val_loss: 0.5508 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7266 - loss: 0.5483 - val_accuracy: 0.7525 - val_loss: 0.5177 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7427 - loss: 0.5221 - val_accuracy: 0.7525 - val_loss: 0.5134 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7539 - loss: 0.5042 - val_accuracy: 0.7582 - val_loss: 0.5060 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7695 - loss: 0.4883 - val_accuracy: 0.7576 - val_loss: 0.5043 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7763 - loss: 0.4770 - val_accuracy: 0.7492 - val_loss: 0.5077 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7891 - loss: 0.4608 - val_accuracy: 0.7554 - val_loss: 0.5096 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7917 - loss: 0.4578 - val_accuracy: 0.7492 - val_loss: 0.5080 - learning_rate: 0.0010
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8094 - loss: 0.4311 - val_accuracy: 0.7582 - val_loss: 0.5071 - learning_rate: 5.0000e-04
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8183 - loss: 0.4146 - val_accuracy: 0.7633 - val_loss: 0.5026 - learning_rate: 5.0000e-04
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8271 - loss: 0.4060 - val_accuracy: 0.7684 - val_loss: 0.5111 - learning_rate: 5.0000e-04
# Epoch 17/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8326 - loss: 0.3964 - val_accuracy: 0.7588 - val_loss: 0.5176 - learning_rate: 5.0000e-04
# Epoch 18/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8288 - loss: 0.3948 - val_accuracy: 0.7638 - val_loss: 0.5208 - learning_rate: 5.0000e-04
# Epoch 19/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8364 - loss: 0.3740 - val_accuracy: 0.7695 - val_loss: 0.5187 - learning_rate: 2.5000e-04
# Epoch 20/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8414 - loss: 0.3726 - val_accuracy: 0.7650 - val_loss: 0.5260 - learning_rate: 2.5000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 2 Validation Results:
# Accuracy: 0.7633
# Balanced Accuracy: 0.7599
# MCC: 0.5246
# Sensitivity: 0.8184
# Specificity: 0.7014
# Confusion Matrix:
# TN: 585, FP: 249
# FN: 170, TP: 766
#
# Confusion Matrix Format:
# [[585 249]
#  [170 766]]
#
# New best weights saved! (MCC: 0.5246)
#
# ==================================================
# Fold 3/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.5182 - loss: 0.7188 - val_accuracy: 0.5706 - val_loss: 0.6827 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5659 - loss: 0.6799 - val_accuracy: 0.5972 - val_loss: 0.6704 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5929 - loss: 0.6636 - val_accuracy: 0.6734 - val_loss: 0.6079 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6927 - loss: 0.5789 - val_accuracy: 0.7260 - val_loss: 0.5533 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7190 - loss: 0.5543 - val_accuracy: 0.7350 - val_loss: 0.5440 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7432 - loss: 0.5294 - val_accuracy: 0.7407 - val_loss: 0.5457 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7461 - loss: 0.5057 - val_accuracy: 0.7424 - val_loss: 0.5442 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7628 - loss: 0.4963 - val_accuracy: 0.7373 - val_loss: 0.5469 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7759 - loss: 0.4757 - val_accuracy: 0.7475 - val_loss: 0.5464 - learning_rate: 5.0000e-04
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7780 - loss: 0.4666 - val_accuracy: 0.7441 - val_loss: 0.5522 - learning_rate: 5.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 3 Validation Results:
# Accuracy: 0.7350
# Balanced Accuracy: 0.7352
# MCC: 0.4701
# Sensitivity: 0.7306
# Specificity: 0.7398
# Confusion Matrix:
# TN: 634, FP: 223
# FN: 246, TP: 667
#
# Confusion Matrix Format:
# [[634 223]
#  [246 667]]
#
# ==================================================
# Fold 4/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.5173 - loss: 0.7651 - val_accuracy: 0.5836 - val_loss: 0.6783 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5827 - loss: 0.6696 - val_accuracy: 0.6531 - val_loss: 0.6325 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6636 - loss: 0.6182 - val_accuracy: 0.6960 - val_loss: 0.5913 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7067 - loss: 0.5796 - val_accuracy: 0.7220 - val_loss: 0.5620 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7356 - loss: 0.5418 - val_accuracy: 0.7305 - val_loss: 0.5481 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7571 - loss: 0.5208 - val_accuracy: 0.7452 - val_loss: 0.5323 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7690 - loss: 0.4993 - val_accuracy: 0.7503 - val_loss: 0.5218 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7852 - loss: 0.4857 - val_accuracy: 0.7424 - val_loss: 0.5254 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7824 - loss: 0.4722 - val_accuracy: 0.7492 - val_loss: 0.5219 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7902 - loss: 0.4564 - val_accuracy: 0.7452 - val_loss: 0.5289 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7980 - loss: 0.4431 - val_accuracy: 0.7475 - val_loss: 0.5240 - learning_rate: 5.0000e-04
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8142 - loss: 0.4191 - val_accuracy: 0.7531 - val_loss: 0.5260 - learning_rate: 5.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 4 Validation Results:
# Accuracy: 0.7503
# Balanced Accuracy: 0.7491
# MCC: 0.5000
# Sensitivity: 0.7864
# Specificity: 0.7118
# Confusion Matrix:
# TN: 610, FP: 247
# FN: 195, TP: 718
#
# Confusion Matrix Format:
# [[610 247]
#  [195 718]]
#
# ==================================================
# Fold 5/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.5124 - loss: 0.7342 - val_accuracy: 0.5277 - val_loss: 0.6851 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5703 - loss: 0.6780 - val_accuracy: 0.5497 - val_loss: 0.6767 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6075 - loss: 0.6500 - val_accuracy: 0.6944 - val_loss: 0.5851 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7186 - loss: 0.5687 - val_accuracy: 0.7158 - val_loss: 0.5493 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7320 - loss: 0.5365 - val_accuracy: 0.7322 - val_loss: 0.5382 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7484 - loss: 0.5176 - val_accuracy: 0.7395 - val_loss: 0.5297 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7632 - loss: 0.5014 - val_accuracy: 0.7373 - val_loss: 0.5343 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7697 - loss: 0.4912 - val_accuracy: 0.7469 - val_loss: 0.5233 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7822 - loss: 0.4644 - val_accuracy: 0.7469 - val_loss: 0.5300 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7898 - loss: 0.4635 - val_accuracy: 0.7395 - val_loss: 0.5388 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8024 - loss: 0.4382 - val_accuracy: 0.7475 - val_loss: 0.5375 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8112 - loss: 0.4212 - val_accuracy: 0.7458 - val_loss: 0.5339 - learning_rate: 5.0000e-04
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8198 - loss: 0.4073 - val_accuracy: 0.7458 - val_loss: 0.5506 - learning_rate: 5.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 5 Validation Results:
# Accuracy: 0.7469
# Balanced Accuracy: 0.7469
# MCC: 0.4935
# Sensitivity: 0.7470
# Specificity: 0.7468
# Confusion Matrix:
# TN: 637, FP: 216
# FN: 232, TP: 685
#
# Confusion Matrix Format:
# [[637 216]
#  [232 685]]
#
# ==================================================
# Cross-validation Complete
# ==================================================
#
# Average Cross-validation Results:
# ACC: 0.7464 ± 0.0102
# BALANCED_ACC: 0.7452 ± 0.0094
# MCC: 0.4925 ± 0.0197
# SN: 0.7762 ± 0.0326
# SP: 0.7141 ± 0.0274
#
# ==================================================
# Final Test Set Evaluation (Best Model)
# ==================================================
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# Test Set Results:
# Accuracy: 0.6997
# Balanced Accuracy: 0.7431
# MCC: 0.2879
# Sensitivity: 0.7958
# Specificity: 0.6904
# Confusion Matrix:
# TN: 1724, FP: 773
# FN: 49, TP: 191
#
# Confusion Matrix Format:
# [[1724  773]
#  [  49  191]]
#
# Warning: Could not save model. Error: Invalid filepath extension for saving. Please add either a `.keras` extension for the native Keras format (recommended) or a `.h5` extension. Use `model.export(filepath)` if you want to export a SavedModel for use with TFLite/TFServing/etc. Received: filepath=best_model.
# Continuing without saving model...

# %%
if __name__ == "__main__":
    model = train_and_evaluate(struct_window=3)
# Out:
# Loading data...
#
# Training set distribution:
# label
# 1    4592
# 0    4258
# Name: count, dtype: int64
#
# Test set distribution:
# label
# 0    2497
# 1     240
# Name: count, dtype: int64
#
# ==================================================
# Fold 1/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.5170 - loss: 0.7148 - val_accuracy: 0.5678 - val_loss: 0.6849 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5610 - loss: 0.6800 - val_accuracy: 0.5718 - val_loss: 0.6743 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5854 - loss: 0.6673 - val_accuracy: 0.6559 - val_loss: 0.6330 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - accuracy: 0.6434 - loss: 0.6276 - val_accuracy: 0.7153 - val_loss: 0.5918 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.6949 - loss: 0.5826 - val_accuracy: 0.7288 - val_loss: 0.5489 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7330 - loss: 0.5494 - val_accuracy: 0.7435 - val_loss: 0.5297 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7406 - loss: 0.5290 - val_accuracy: 0.7469 - val_loss: 0.5233 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.7480 - loss: 0.5189 - val_accuracy: 0.7458 - val_loss: 0.5180 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7595 - loss: 0.4943 - val_accuracy: 0.7446 - val_loss: 0.5248 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.7720 - loss: 0.4836 - val_accuracy: 0.7429 - val_loss: 0.5147 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - accuracy: 0.7721 - loss: 0.4808 - val_accuracy: 0.7469 - val_loss: 0.5134 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - accuracy: 0.7807 - loss: 0.4665 - val_accuracy: 0.7435 - val_loss: 0.5202 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - accuracy: 0.8040 - loss: 0.4522 - val_accuracy: 0.7429 - val_loss: 0.5138 - learning_rate: 0.0010
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.7981 - loss: 0.4419 - val_accuracy: 0.7446 - val_loss: 0.5202 - learning_rate: 0.0010
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - accuracy: 0.8136 - loss: 0.4180 - val_accuracy: 0.7429 - val_loss: 0.5254 - learning_rate: 5.0000e-04
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.8218 - loss: 0.4109 - val_accuracy: 0.7463 - val_loss: 0.5323 - learning_rate: 5.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#
# Fold 1 Validation Results:
# Accuracy: 0.7469
# Balanced Accuracy: 0.7440
# MCC: 0.4978
# Sensitivity: 0.8368
# Specificity: 0.6511
# Confusion Matrix:
# TN: 558, FP: 299
# FN: 149, TP: 764
#
# Confusion Matrix Format:
# [[558 299]
#  [149 764]]
#
# New best weights saved! (MCC: 0.4978)
#
# ==================================================
# Fold 2/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.5109 - loss: 0.7148 - val_accuracy: 0.5712 - val_loss: 0.6839 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - accuracy: 0.5716 - loss: 0.6754 - val_accuracy: 0.6362 - val_loss: 0.6305 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.6811 - loss: 0.6007 - val_accuracy: 0.7294 - val_loss: 0.5432 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.7224 - loss: 0.5529 - val_accuracy: 0.7429 - val_loss: 0.5211 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.7443 - loss: 0.5204 - val_accuracy: 0.7531 - val_loss: 0.5078 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.7532 - loss: 0.5106 - val_accuracy: 0.7480 - val_loss: 0.5052 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.7679 - loss: 0.4926 - val_accuracy: 0.7627 - val_loss: 0.5050 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.7727 - loss: 0.4802 - val_accuracy: 0.7548 - val_loss: 0.5053 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.7842 - loss: 0.4626 - val_accuracy: 0.7452 - val_loss: 0.5106 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.7958 - loss: 0.4437 - val_accuracy: 0.7508 - val_loss: 0.5134 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - accuracy: 0.8023 - loss: 0.4243 - val_accuracy: 0.7621 - val_loss: 0.5135 - learning_rate: 5.0000e-04
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.8229 - loss: 0.4047 - val_accuracy: 0.7576 - val_loss: 0.5221 - learning_rate: 5.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#
# Fold 2 Validation Results:
# Accuracy: 0.7627
# Balanced Accuracy: 0.7574
# MCC: 0.5261
# Sensitivity: 0.8494
# Specificity: 0.6655
# Confusion Matrix:
# TN: 555, FP: 279
# FN: 141, TP: 795
#
# Confusion Matrix Format:
# [[555 279]
#  [141 795]]
#
# New best weights saved! (MCC: 0.5261)
#
# ==================================================
# Fold 3/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.5174 - loss: 0.7266 - val_accuracy: 0.5791 - val_loss: 0.6814 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5759 - loss: 0.6758 - val_accuracy: 0.6424 - val_loss: 0.6375 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6373 - loss: 0.6397 - val_accuracy: 0.6678 - val_loss: 0.6139 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6769 - loss: 0.6164 - val_accuracy: 0.6797 - val_loss: 0.6021 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6918 - loss: 0.5929 - val_accuracy: 0.6949 - val_loss: 0.5820 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7140 - loss: 0.5640 - val_accuracy: 0.6977 - val_loss: 0.5763 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7370 - loss: 0.5391 - val_accuracy: 0.7119 - val_loss: 0.5702 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7496 - loss: 0.5210 - val_accuracy: 0.7186 - val_loss: 0.5667 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7626 - loss: 0.4962 - val_accuracy: 0.7249 - val_loss: 0.5667 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7773 - loss: 0.4747 - val_accuracy: 0.7147 - val_loss: 0.6024 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.7834 - loss: 0.4588 - val_accuracy: 0.7186 - val_loss: 0.5925 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8054 - loss: 0.4341 - val_accuracy: 0.7232 - val_loss: 0.5926 - learning_rate: 5.0000e-04
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.8118 - loss: 0.4179 - val_accuracy: 0.7282 - val_loss: 0.5897 - learning_rate: 5.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#
# Fold 3 Validation Results:
# Accuracy: 0.7186
# Balanced Accuracy: 0.7183
# MCC: 0.4367
# Sensitivity: 0.7284
# Specificity: 0.7083
# Confusion Matrix:
# TN: 607, FP: 250
# FN: 248, TP: 665
#
# Confusion Matrix Format:
# [[607 250]
#  [248 665]]
#
# ==================================================
# Fold 4/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.5271 - loss: 0.7229 - val_accuracy: 0.5616 - val_loss: 0.6814 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5560 - loss: 0.6792 - val_accuracy: 0.6458 - val_loss: 0.6351 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6581 - loss: 0.6279 - val_accuracy: 0.7102 - val_loss: 0.5659 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7159 - loss: 0.5655 - val_accuracy: 0.7350 - val_loss: 0.5391 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7400 - loss: 0.5339 - val_accuracy: 0.7401 - val_loss: 0.5267 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7571 - loss: 0.5095 - val_accuracy: 0.7486 - val_loss: 0.5228 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7606 - loss: 0.4999 - val_accuracy: 0.7582 - val_loss: 0.5155 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7714 - loss: 0.4843 - val_accuracy: 0.7588 - val_loss: 0.5132 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7849 - loss: 0.4733 - val_accuracy: 0.7520 - val_loss: 0.5170 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7879 - loss: 0.4624 - val_accuracy: 0.7576 - val_loss: 0.5121 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7986 - loss: 0.4432 - val_accuracy: 0.7508 - val_loss: 0.5157 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8056 - loss: 0.4376 - val_accuracy: 0.7531 - val_loss: 0.5266 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8139 - loss: 0.4298 - val_accuracy: 0.7542 - val_loss: 0.5220 - learning_rate: 0.0010
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8235 - loss: 0.4043 - val_accuracy: 0.7514 - val_loss: 0.5227 - learning_rate: 5.0000e-04
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8292 - loss: 0.3912 - val_accuracy: 0.7503 - val_loss: 0.5266 - learning_rate: 5.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 4 Validation Results:
# Accuracy: 0.7576
# Balanced Accuracy: 0.7575
# MCC: 0.5149
# Sensitivity: 0.7612
# Specificity: 0.7538
# Confusion Matrix:
# TN: 646, FP: 211
# FN: 218, TP: 695
#
# Confusion Matrix Format:
# [[646 211]
#  [218 695]]
#
# ==================================================
# Fold 5/5
# ==================================================
# Epoch 1/50
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.5237 - loss: 0.7167 - val_accuracy: 0.5887 - val_loss: 0.6737 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6013 - loss: 0.6607 - val_accuracy: 0.6706 - val_loss: 0.6251 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6601 - loss: 0.6144 - val_accuracy: 0.6712 - val_loss: 0.6143 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7138 - loss: 0.5763 - val_accuracy: 0.7175 - val_loss: 0.5644 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7271 - loss: 0.5461 - val_accuracy: 0.7266 - val_loss: 0.5516 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7461 - loss: 0.5176 - val_accuracy: 0.7322 - val_loss: 0.5455 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7630 - loss: 0.4932 - val_accuracy: 0.7367 - val_loss: 0.5312 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7666 - loss: 0.4879 - val_accuracy: 0.7401 - val_loss: 0.5319 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7811 - loss: 0.4670 - val_accuracy: 0.7345 - val_loss: 0.5304 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7935 - loss: 0.4508 - val_accuracy: 0.7435 - val_loss: 0.5503 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8051 - loss: 0.4302 - val_accuracy: 0.7379 - val_loss: 0.5526 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8120 - loss: 0.4225 - val_accuracy: 0.7328 - val_loss: 0.5655 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8329 - loss: 0.3861 - val_accuracy: 0.7350 - val_loss: 0.5623 - learning_rate: 5.0000e-04
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8364 - loss: 0.3716 - val_accuracy: 0.7345 - val_loss: 0.5871 - learning_rate: 5.0000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold 5 Validation Results:
# Accuracy: 0.7345
# Balanced Accuracy: 0.7335
# MCC: 0.4679
# Sensitivity: 0.7590
# Specificity: 0.7081
# Confusion Matrix:
# TN: 604, FP: 249
# FN: 221, TP: 696
#
# Confusion Matrix Format:
# [[604 249]
#  [221 696]]
#
# ==================================================
# Cross-validation Complete
# ==================================================
#
# Average Cross-validation Results:
# ACC: 0.7441 ± 0.0160
# BALANCED_ACC: 0.7421 ± 0.0149
# MCC: 0.4887 ± 0.0326
# SN: 0.7870 ± 0.0474
# SP: 0.6973 ± 0.0363
#
# ==================================================
# Final Test Set Evaluation (Best Model)
# ==================================================
# /Users/hai/miniconda3/envs/bioinf/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# Test Set Results:
# Accuracy: 0.6712
# Balanced Accuracy: 0.7388
# MCC: 0.2776
# Sensitivity: 0.8208
# Specificity: 0.6568
# Confusion Matrix:
# TN: 1640, FP: 857
# FN: 43, TP: 197
#
# Confusion Matrix Format:
# [[1640  857]
#  [  43  197]]
#
# Warning: Could not save model. Error: Invalid filepath extension for saving. Please add either a `.keras` extension for the native Keras format (recommended) or a `.h5` extension. Use `model.export(filepath)` if you want to export a SavedModel for use with TFLite/TFServing/etc. Received: filepath=best_model.
# Continuing without saving model...
